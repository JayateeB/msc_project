# %%
import pandas as pd
import csv

# %%
path = "/Users/jay/MSC_WSBDA/MSc_Thesis/Msc_project/Data/"

# %%
df_neigh = pd.read_csv(path+'simulation_result_key_node_avg_neighbour_degree_top_10.csv')

# %%
df_neigh
# Out:
#        Unnamed: 0         id  time_lapsed  favourites_count  followers_count  \
# 0               0  214328887         60.0               548             2090
# 1               1   34428380         30.0                38           305257
# 2               2   17116707         60.0                31            11756
# 3               3   28465635         60.0              4449            57992
# 4               4  380580781         60.0              1968            15033
# 5               5   18996905         30.0              2158           284075
# 6               6  221036078         90.0               309             2121
# 7               7  153460275         60.0                74             4710
# 8               8  107830991         90.0               350            11627
# 9               9   17868918         30.0                 9            16996
# 10             10  151338729         60.0              3588            41712
# ...

# %%
df_neigh.groupby(['time_lapsed']).count()['id']
# Out:
# time_lapsed
# 0.0         18
# 30.0      3695
# 60.0     18378
# 90.0     19584
# 120.0     9185
# 150.0     3365
# 180.0     1262
# 210.0      485
# 240.0      258
# 270.0      150
# 300.0       66
# 330.0       11
# 360.0        4
# 390.0        1
# Name: id, dtype: int64

# %%
df_degree = pd.read_csv(path+'simulation_result_key_node_degree_top_10.csv')

# %%
df_degree.groupby(['time_lapsed']).count()['id']
# Out:
# time_lapsed
# 0.0       4558
# 30.0     20230
# 60.0     18885
# 90.0      8146
# 120.0     2799
# 150.0      996
# 180.0      422
# 210.0      245
# 240.0      125
# 270.0       46
# 300.0        3
# 330.0        2
# 360.0        1
# Name: id, dtype: int64
