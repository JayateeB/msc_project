# %%
import pandas as pd
import csv
import pickle
import numpy as np
from IPython.display import display
import multiprocessing
from multiprocessing import Pool
import math
from tqdm import tqdm
import time
import traceback
from sklearn.externals import joblib
import xgboost as xgb
import json
import time

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.model_selection import *
from sklearn.metrics import *
from sklearn import svm
from pandas import *
import pandas as pd
from pprint import pprint
import sys
#import matplotlib.pyplot as plt
from sklearn.utils import resample

#import shap

import multiprocessing
cpu_count = multiprocessing.cpu_count()

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
#path = "/Users/jay/MSC_WSBDA/MSc_Thesis/Msc_project/Data/"
path = '/Users/syamantak/JayateeB/new_files/data/'
event = 'nyc'
start_hour = 7

# %%
def load_pickle_file(pickled_file):
    print(f'Loading data file from {pickled_file}')
    infile = open(pickled_file,'rb')
    unpickled_file = pickle.load(infile)
    print(f'Loaded {len(unpickled_file)} entries')
    infile.close()
    return unpickled_file
          
    
def save_pickle_file(path, data):
    print('Dumping data to path {}'.format(path))
    with open(path, 'wb') as file:
        pickle.dump(data, file)
    print('Finished dumping data to path {}'.format(path))


def mean(numbers):
    return float(sum(numbers)) / max(len(numbers), 1)


def safe_division(x, y):
    if y == 0:
        return 0
    else:
        return x/y

# %%
initial_features = load_pickle_file(path+event+'_'+str(start_hour)+'_hrs_data.pkl')
users = load_pickle_file(path+'nyc/'+event+"_users.dat")
users.reset_index(drop =True , inplace =True)
# Out:
# Loading data file from /Users/syamantak/JayateeB/new_files/data/nyc_7_hrs_data.pkl
# Loaded 135912 entries
# Loading data file from /Users/syamantak/JayateeB/new_files/data/nyc/nyc_users.dat
# Loaded 135912 entries

# %%
def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="red" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="red" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()

# %%
def prepare_data(initial_features):
    df = initial_features
    
    df['label']=df['infected_status'].apply(lambda x: 1 if x == True else 0)
    df = df.reset_index(drop=True)
    
    #df = df.drop(columns = ['user_id', 'infected_status', 'infection_time', 'followers_list'],axis = 1)
    df = df.drop(columns = ['user_id', 'infected_status', 'infection_time'],axis = 1)
    
    # Converting all type to float, to prepare for feature selection
    df = df.astype('float')
    # Reset index, with drop equals to true to avoid setting old index as a new column
    df = df.reset_index(drop=True)
    # Visualize distribution
    print('[Original] data counts, with uninfected (0): {}, infected (1): {}'.format(
        df['label'].value_counts()[0],
        df['label'].value_counts()[1]
    ))
    df.groupby(['TwM_tCurrent','label']).size().unstack(fill_value=0).plot.bar(title='Original Data Distribution')
    
    columns = list(df.columns)
    columns.remove('label')
    
    X = df[columns]
    y = df[['label']]
    return df, X, y

# %%
# 1. Prepare
df, X, y = prepare_data(initial_features)
# Out:
# [Original] data counts, with uninfected (0): 56676, infected (1): 79236

# %%
feature_columns = X.columns
print('There are {} Features'.format(len(feature_columns)))
# Out:
# There are 88 Features

# %%
def upsample(df):
    # Separate majority and minority classes
    df_majority = df[df.label==0] # Uninfected is the major class
    df_minority = df[df.label==1] # Infected is the minor class

    # Upsample minority class
    df_minority_upsampled = resample(df_minority, 
                                     replace=True,     # sample with replacement
                                     n_samples=len(df_majority),    # to match majority class
                                     random_state=123) # reproducible results

    # Combine majority class with upsampled minority class
    df_upsampled = pd.concat([df_majority, df_minority_upsampled])

    # Display new class counts
    print(df_upsampled.label.value_counts())
    
    return df_upsampled

# %%
def downsample(df):
    # Separate majority and minority classes
    df_majority = df[df.label==0] # Uninfected is the major class
    df_minority = df[df.label==1] # Infected is the minor class

    # Downsample majority class
    df_majority_downsampled = resample(df_majority, 
                                     replace=False,    # sample without replacement
                                     n_samples=len(df_minority),     # to match minority class
                                     random_state=123) # reproducible results

    # Combine minority class with downsampled majority class
    df_downsampled = pd.concat([df_majority_downsampled, df_minority])

    # Display new class counts
    print(df_downsampled.label.value_counts())
    
    return df_downsampled

# %%
def train(df, X, y, params, n_folds, num_boost_round, rebalance_method):
    # 2. N Fold Split
    # Stratified K-Folds cross-validator
    # Provides train/test indices to split data in train/test sets. 
    # This cross-validation object is a variation of KFold that returns stratified folds. 
    # The folds are made by preserving the percentage of samples for each class.
    skf = StratifiedKFold(n_splits=n_folds, shuffle=True)
    
    corrDataframe = pd.DataFrame()    
    mse = []
    acc = []
    roc = []
    F1 = []
    auc = []
    auc_t = []
    acc_t = []
    fold_count = 0
    t_current = 210
    number_of_features = len(X.columns)

    print("Start cross validation")
    for train, test in skf.split(X, y):
        print("===Processing fold %s===" % fold_count)
        train_fold = df.loc[train]
        test_fold = df.loc[test]

        # 3. Rebalance
        if rebalance_method == 'up':
            train_fold = upsample(train_fold)
        if rebalance_method == 'down':
            train_fold = downsample(train_fold)
         
        # 4. Feature Selection
#         corr = train_fold.corr()['label'][train_fold.corr()['label'] < 1].abs()
#         corr = corr.sort_values(ascending=False)
#         corrDataframe = corrDataframe.append(pd.DataFrame(corr.rename('cv{}'.format(fold_count))).T)
#         features = corr.index[range(number_of_features)].values
        features = X.columns
        
        # 5. Training
        # Fit Model
        xgtrain = xgb.DMatrix(train_fold[features].values, train_fold['label'].values)
        xgtest = xgb.DMatrix(test_fold[features].values, test_fold['label'].values)
        evallist = [(xgtrain, 'train'),(xgtest,'eval')]
#         evallist = []
        
        bst = xgb.train(params, xgtrain, 
                        num_boost_round = num_boost_round, 
                        evals = evallist)

        # 6. Testing
        # Check MSE on test set
        
        test_fold_t = test_fold[test_fold.TwM_tCurrent == t_current]
#             xgtest = xgb.DMatrix(test_fold[features].values)
        xgtest_t = xgb.DMatrix(test_fold_t[features].values)
        pred = bst.predict(xgtest)
        pred_t = bst.predict(xgtest_t)

        mse.append(mean_squared_error(test_fold['label'], pred))
        roc.append(roc_auc_score(test_fold['label'], pred))
        #auc_t.append(roc_auc_score(test_fold_t['label'], pred_t))

        acc.append(accuracy_score(test_fold['label'], (pred>0.5).astype(int)))
        acc_t.append(accuracy_score(test_fold_t['label'], (pred_t>0.5).astype(int)))
        F1.append(f1_score(test_fold['label'],(pred>0.5).astype(int)))
        cm = confusion_matrix(test_fold['label'], (pred>0.5).astype(int))
        plot_confusion_matrix(cm, 
                              normalize    = True,
                              target_names = ['Uninfected', 'Infected'],
                              title        = "Confusion Matrix, Normalized")


        fold_count += 1
        # Done with the fold
    print("Finished cross validation")
    print("MSE: {} ".format(DataFrame(mse).mean()))
    print("ACC: {} ".format(DataFrame(acc).mean()))
    print("AUC: {} ".format(DataFrame(roc).mean()))
#     print("F1: {} ".format(DataFrame(F1).mean()))
    print("ACC for t at {}: {} ".format(t_current, DataFrame(acc_t).mean()))
    corrDataframe = corrDataframe.T
    corrDataframe['average corr'] = corrDataframe.mean(numeric_only=True, axis=1)
    print(corrDataframe.sort_values(by=['average corr'], ascending=False).to_string())

    return bst

# %%
#xgboost
param = {
    'max_depth':3,
    # Step size shrinkage used in update to prevents overfitting. 
    # After each boosting step, we can directly get the weights of new features, 
    # and eta shrinks the feature weights to make the boosting process more conservative.
    'eta': 0.1,
    # Minimum loss reduction required to make a further partition on a leaf node of the tree. 
    # The larger gamma is, the more conservative the algorithm will be.
    'gamma':10,
    # Minimum sum of instance weight (hessian) needed in a child. 
    # If the tree partition step results in a leaf node with the sum of instance weight less than min_child_weight, 
    # then the building process will give up further partitioning.
    # The larger min_child_weight is, the more conservative the algorithm will be.
    'min_child_weight':10,
    'silent': 1, # 0 means printing running messages, 1 means silent mode
    'objective': 'binary:logistic',
    'subsample': 0.9
}
param['nthread'] = cpu_count
param['eval_metric'] = ['auc']
num_boost_round = 1000
rebalance_method = 'up'

# %%
xgb_model = train(df, X, y, param, 2, num_boost_round, rebalance_method)
# Out:
# Start cross validation
# ===Processing fold 0===
# 1.0    28338
# 0.0    28338
# Name: label, dtype: int64
# [0]	train-auc:0.662134	eval-auc:0.660094
# [1]	train-auc:0.677448	eval-auc:0.674699
# [2]	train-auc:0.682446	eval-auc:0.680672
# [3]	train-auc:0.684138	eval-auc:0.683272
# [4]	train-auc:0.685936	eval-auc:0.685736
# [5]	train-auc:0.687538	eval-auc:0.687623
# [6]	train-auc:0.687604	eval-auc:0.687534
# [7]	train-auc:0.692215	eval-auc:0.691647
# [8]	train-auc:0.693613	eval-auc:0.693029
# [9]	train-auc:0.696128	eval-auc:0.695659
# [10]	train-auc:0.698426	eval-auc:0.697866
# [11]	train-auc:0.698416	eval-auc:0.697818
# [12]	train-auc:0.698826	eval-auc:0.698244
# [13]	train-auc:0.701429	eval-auc:0.700767
# [14]	train-auc:0.702824	eval-auc:0.701796
# [15]	train-auc:0.704459	eval-auc:0.702987
# [16]	train-auc:0.705642	eval-auc:0.704178
# [17]	train-auc:0.70723	eval-auc:0.705282
# [18]	train-auc:0.70822	eval-auc:0.706118
# [19]	train-auc:0.709314	eval-auc:0.70694
# [20]	train-auc:0.709984	eval-auc:0.707505
# [21]	train-auc:0.710895	eval-auc:0.708261
# [22]	train-auc:0.711382	eval-auc:0.708846
# [23]	train-auc:0.712377	eval-auc:0.709635
# [24]	train-auc:0.712928	eval-auc:0.710063
# [25]	train-auc:0.71389	eval-auc:0.710736
# [26]	train-auc:0.714372	eval-auc:0.71117
# [27]	train-auc:0.715356	eval-auc:0.71178
# [28]	train-auc:0.716523	eval-auc:0.712788
# [29]	train-auc:0.716987	eval-auc:0.713241
# [30]	train-auc:0.717652	eval-auc:0.713664
# [31]	train-auc:0.718204	eval-auc:0.714145
# [32]	train-auc:0.71891	eval-auc:0.714776
# [33]	train-auc:0.71942	eval-auc:0.714931
# [34]	train-auc:0.720591	eval-auc:0.716193
# [35]	train-auc:0.72085	eval-auc:0.716383
# [36]	train-auc:0.721803	eval-auc:0.717084
# [37]	train-auc:0.722314	eval-auc:0.717445
# [38]	train-auc:0.722664	eval-auc:0.717821
# [39]	train-auc:0.723484	eval-auc:0.718433
# [40]	train-auc:0.724171	eval-auc:0.718907
# [41]	train-auc:0.724419	eval-auc:0.719134
# [42]	train-auc:0.725066	eval-auc:0.719666
# [43]	train-auc:0.725221	eval-auc:0.719775
# [44]	train-auc:0.725917	eval-auc:0.720501
# [45]	train-auc:0.72624	eval-auc:0.720519
# [46]	train-auc:0.726772	eval-auc:0.720854
# [47]	train-auc:0.727386	eval-auc:0.721169
# [48]	train-auc:0.727989	eval-auc:0.72164
# [49]	train-auc:0.72835	eval-auc:0.721998
# [50]	train-auc:0.728906	eval-auc:0.722411
# [51]	train-auc:0.729371	eval-auc:0.722771
# [52]	train-auc:0.729648	eval-auc:0.722974
# [53]	train-auc:0.729809	eval-auc:0.723035
# [54]	train-auc:0.730151	eval-auc:0.723179
# [55]	train-auc:0.730409	eval-auc:0.723204
# [56]	train-auc:0.730692	eval-auc:0.723322
# [57]	train-auc:0.731108	eval-auc:0.723482
# [58]	train-auc:0.731555	eval-auc:0.723814
# [59]	train-auc:0.731879	eval-auc:0.723941
# [60]	train-auc:0.732464	eval-auc:0.72436
# [61]	train-auc:0.732841	eval-auc:0.724454
# [62]	train-auc:0.733184	eval-auc:0.72471
# [63]	train-auc:0.733579	eval-auc:0.725008
# [64]	train-auc:0.733833	eval-auc:0.725202
# [65]	train-auc:0.734169	eval-auc:0.725394
# [66]	train-auc:0.734728	eval-auc:0.725737
# [67]	train-auc:0.735007	eval-auc:0.72591
# [68]	train-auc:0.735499	eval-auc:0.726267
# [69]	train-auc:0.735955	eval-auc:0.726483
# [70]	train-auc:0.736312	eval-auc:0.726665
# [71]	train-auc:0.736567	eval-auc:0.726867
# [72]	train-auc:0.736729	eval-auc:0.72694
# [73]	train-auc:0.737149	eval-auc:0.727095
# [74]	train-auc:0.73743	eval-auc:0.727204
# [75]	train-auc:0.737757	eval-auc:0.727332
# [76]	train-auc:0.73802	eval-auc:0.727505
# [77]	train-auc:0.738236	eval-auc:0.727574
# [78]	train-auc:0.73859	eval-auc:0.727847
# [79]	train-auc:0.738838	eval-auc:0.727949
# [80]	train-auc:0.738987	eval-auc:0.72809
# [81]	train-auc:0.739179	eval-auc:0.728172
# [82]	train-auc:0.739272	eval-auc:0.728212
# [83]	train-auc:0.739453	eval-auc:0.728427
# [84]	train-auc:0.739703	eval-auc:0.728511
# [85]	train-auc:0.739947	eval-auc:0.728679
# [86]	train-auc:0.740259	eval-auc:0.728772
# [87]	train-auc:0.740528	eval-auc:0.728884
# [88]	train-auc:0.740654	eval-auc:0.728926
# [89]	train-auc:0.74079	eval-auc:0.728989
# [90]	train-auc:0.741088	eval-auc:0.729057
# [91]	train-auc:0.741391	eval-auc:0.72918
# [92]	train-auc:0.741607	eval-auc:0.729289
# [93]	train-auc:0.741812	eval-auc:0.729385
# [94]	train-auc:0.742059	eval-auc:0.729456
# [95]	train-auc:0.742231	eval-auc:0.729507
# [96]	train-auc:0.74263	eval-auc:0.729664
# [97]	train-auc:0.742975	eval-auc:0.729764
# [98]	train-auc:0.743052	eval-auc:0.729837
# [99]	train-auc:0.743399	eval-auc:0.729894
# [100]	train-auc:0.743632	eval-auc:0.729969
# [101]	train-auc:0.743754	eval-auc:0.729949
# [102]	train-auc:0.74395	eval-auc:0.730051
# [103]	train-auc:0.744031	eval-auc:0.730043
# [104]	train-auc:0.744146	eval-auc:0.730131
# [105]	train-auc:0.744333	eval-auc:0.730174
# [106]	train-auc:0.744542	eval-auc:0.73027
# [107]	train-auc:0.744802	eval-auc:0.730267
# [108]	train-auc:0.745049	eval-auc:0.730366
# [109]	train-auc:0.745201	eval-auc:0.730425
# [110]	train-auc:0.745473	eval-auc:0.730583
# [111]	train-auc:0.745659	eval-auc:0.730686
# [112]	train-auc:0.745941	eval-auc:0.730747
# [113]	train-auc:0.746023	eval-auc:0.730766
# [114]	train-auc:0.746288	eval-auc:0.730883
# [115]	train-auc:0.74637	eval-auc:0.73092
# [116]	train-auc:0.7466	eval-auc:0.731018
# [117]	train-auc:0.746925	eval-auc:0.731167
# [118]	train-auc:0.74716	eval-auc:0.731264
# [119]	train-auc:0.747247	eval-auc:0.731318
# [120]	train-auc:0.747492	eval-auc:0.731462
# [121]	train-auc:0.747783	eval-auc:0.731517
# [122]	train-auc:0.747972	eval-auc:0.73155
# [123]	train-auc:0.74802	eval-auc:0.731571
# [124]	train-auc:0.748133	eval-auc:0.73162
# [125]	train-auc:0.748346	eval-auc:0.731667
# [126]	train-auc:0.74857	eval-auc:0.731891
# [127]	train-auc:0.748734	eval-auc:0.731947
# [128]	train-auc:0.748814	eval-auc:0.731982
# [129]	train-auc:0.749067	eval-auc:0.732104
# [130]	train-auc:0.749178	eval-auc:0.732145
# [131]	train-auc:0.749407	eval-auc:0.732191
# [132]	train-auc:0.749436	eval-auc:0.732172
# [133]	train-auc:0.749658	eval-auc:0.732285
# [134]	train-auc:0.749933	eval-auc:0.732366
# [135]	train-auc:0.750165	eval-auc:0.732424
# [136]	train-auc:0.750316	eval-auc:0.732478
# [137]	train-auc:0.750533	eval-auc:0.732532
# [138]	train-auc:0.750699	eval-auc:0.732556
# [139]	train-auc:0.751032	eval-auc:0.732757
# [140]	train-auc:0.751221	eval-auc:0.732786
# [141]	train-auc:0.751462	eval-auc:0.732869
# [142]	train-auc:0.751621	eval-auc:0.732879
# [143]	train-auc:0.751784	eval-auc:0.73285
# [144]	train-auc:0.751952	eval-auc:0.732967
# [145]	train-auc:0.752132	eval-auc:0.733052
# [146]	train-auc:0.752295	eval-auc:0.733002
# [147]	train-auc:0.752469	eval-auc:0.73299
# [148]	train-auc:0.752496	eval-auc:0.732992
# [149]	train-auc:0.752668	eval-auc:0.733039
# [150]	train-auc:0.752929	eval-auc:0.733135
# [151]	train-auc:0.753091	eval-auc:0.733255
# [152]	train-auc:0.753288	eval-auc:0.733287
# [153]	train-auc:0.753447	eval-auc:0.733306
# [154]	train-auc:0.753601	eval-auc:0.733343
# [155]	train-auc:0.753848	eval-auc:0.733393
# [156]	train-auc:0.754033	eval-auc:0.733445
# [157]	train-auc:0.754156	eval-auc:0.733504
# [158]	train-auc:0.754386	eval-auc:0.733599
# [159]	train-auc:0.75452	eval-auc:0.733615
# [160]	train-auc:0.754719	eval-auc:0.733722
# [161]	train-auc:0.754819	eval-auc:0.733763
# [162]	train-auc:0.754955	eval-auc:0.7338
# [163]	train-auc:0.754955	eval-auc:0.7338
# [164]	train-auc:0.75508	eval-auc:0.733826
# [165]	train-auc:0.755321	eval-auc:0.733988
# [166]	train-auc:0.755495	eval-auc:0.733994
# [167]	train-auc:0.755495	eval-auc:0.733994
# [168]	train-auc:0.755537	eval-auc:0.734025
# [169]	train-auc:0.755537	eval-auc:0.734025
# [170]	train-auc:0.755615	eval-auc:0.73403
# [171]	train-auc:0.755615	eval-auc:0.73403
# [172]	train-auc:0.755829	eval-auc:0.73411
# [173]	train-auc:0.755947	eval-auc:0.734117
# [174]	train-auc:0.756078	eval-auc:0.734127
# [175]	train-auc:0.756306	eval-auc:0.734138
# [176]	train-auc:0.756306	eval-auc:0.734138
# [177]	train-auc:0.756471	eval-auc:0.734139
# [178]	train-auc:0.756471	eval-auc:0.734139
# [179]	train-auc:0.756586	eval-auc:0.73416
# [180]	train-auc:0.756647	eval-auc:0.734172
# [181]	train-auc:0.756763	eval-auc:0.734219
# [182]	train-auc:0.756973	eval-auc:0.734266
# [183]	train-auc:0.757022	eval-auc:0.734289
# [184]	train-auc:0.757074	eval-auc:0.734294
# [185]	train-auc:0.757251	eval-auc:0.734363
# [186]	train-auc:0.757314	eval-auc:0.734351
# [187]	train-auc:0.757462	eval-auc:0.734381
# [188]	train-auc:0.757537	eval-auc:0.734371
# [189]	train-auc:0.757816	eval-auc:0.734607
# [190]	train-auc:0.758039	eval-auc:0.734649
# [191]	train-auc:0.758216	eval-auc:0.734689
# [192]	train-auc:0.75835	eval-auc:0.734759
# [193]	train-auc:0.758514	eval-auc:0.734774
# [194]	train-auc:0.758633	eval-auc:0.734772
# [195]	train-auc:0.758792	eval-auc:0.73483
# [196]	train-auc:0.758792	eval-auc:0.73483
# [197]	train-auc:0.759	eval-auc:0.734819
# [198]	train-auc:0.759	eval-auc:0.734819
# [199]	train-auc:0.759058	eval-auc:0.734804
# [200]	train-auc:0.759147	eval-auc:0.734838
# [201]	train-auc:0.759327	eval-auc:0.734867
# [202]	train-auc:0.759615	eval-auc:0.73492
# [203]	train-auc:0.759765	eval-auc:0.734942
# [204]	train-auc:0.759963	eval-auc:0.734988
# [205]	train-auc:0.760268	eval-auc:0.735074
# [206]	train-auc:0.76043	eval-auc:0.735087
# [207]	train-auc:0.760537	eval-auc:0.735055
# [208]	train-auc:0.760692	eval-auc:0.735037
# [209]	train-auc:0.760893	eval-auc:0.735096
# [210]	train-auc:0.760929	eval-auc:0.735087
# [211]	train-auc:0.761131	eval-auc:0.735158
# [212]	train-auc:0.761229	eval-auc:0.735164
# [213]	train-auc:0.761355	eval-auc:0.735232
# [214]	train-auc:0.761554	eval-auc:0.735267
# [215]	train-auc:0.761661	eval-auc:0.735263
# [216]	train-auc:0.761721	eval-auc:0.735301
# [217]	train-auc:0.761842	eval-auc:0.735305
# [218]	train-auc:0.76197	eval-auc:0.73526
# [219]	train-auc:0.762273	eval-auc:0.735428
# [220]	train-auc:0.762509	eval-auc:0.735519
# [221]	train-auc:0.762627	eval-auc:0.735555
# [222]	train-auc:0.762845	eval-auc:0.735538
# [223]	train-auc:0.762845	eval-auc:0.735538
# [224]	train-auc:0.763038	eval-auc:0.735631
# [225]	train-auc:0.763169	eval-auc:0.735686
# [226]	train-auc:0.763337	eval-auc:0.735719
# [227]	train-auc:0.763539	eval-auc:0.735809
# [228]	train-auc:0.763584	eval-auc:0.735824
# [229]	train-auc:0.763633	eval-auc:0.73583
# [230]	train-auc:0.763633	eval-auc:0.73583
# [231]	train-auc:0.763796	eval-auc:0.735836
# [232]	train-auc:0.764032	eval-auc:0.735905
# [233]	train-auc:0.764209	eval-auc:0.735922
# [234]	train-auc:0.764305	eval-auc:0.735925
# [235]	train-auc:0.7644	eval-auc:0.73593
# [236]	train-auc:0.764518	eval-auc:0.735921
# [237]	train-auc:0.764721	eval-auc:0.735966
# [238]	train-auc:0.764919	eval-auc:0.736027
# [239]	train-auc:0.764919	eval-auc:0.736027
# [240]	train-auc:0.765005	eval-auc:0.736048
# [241]	train-auc:0.765125	eval-auc:0.735993
# [242]	train-auc:0.765433	eval-auc:0.736101
# [243]	train-auc:0.765623	eval-auc:0.73613
# [244]	train-auc:0.765749	eval-auc:0.736147
# [245]	train-auc:0.765936	eval-auc:0.736142
# [246]	train-auc:0.766041	eval-auc:0.73615
# [247]	train-auc:0.766261	eval-auc:0.736189
# [248]	train-auc:0.766377	eval-auc:0.736209
# [249]	train-auc:0.766515	eval-auc:0.736254
# [250]	train-auc:0.766685	eval-auc:0.73629
# [251]	train-auc:0.766931	eval-auc:0.736352
# [252]	train-auc:0.767016	eval-auc:0.736354
# [253]	train-auc:0.76713	eval-auc:0.736327
# [254]	train-auc:0.76713	eval-auc:0.736327
# [255]	train-auc:0.767271	eval-auc:0.736326
# [256]	train-auc:0.767469	eval-auc:0.736379
# [257]	train-auc:0.767608	eval-auc:0.736399
# [258]	train-auc:0.76769	eval-auc:0.736319
# [259]	train-auc:0.76769	eval-auc:0.736319
# [260]	train-auc:0.767812	eval-auc:0.736328
# [261]	train-auc:0.767947	eval-auc:0.736293
# [262]	train-auc:0.767975	eval-auc:0.736275
# [263]	train-auc:0.768043	eval-auc:0.73628
# [264]	train-auc:0.768104	eval-auc:0.736264
# [265]	train-auc:0.768219	eval-auc:0.736336
# [266]	train-auc:0.768337	eval-auc:0.736339
# [267]	train-auc:0.768337	eval-auc:0.736339
# [268]	train-auc:0.768443	eval-auc:0.736362
# [269]	train-auc:0.768443	eval-auc:0.736362
# [270]	train-auc:0.768443	eval-auc:0.736362
# [271]	train-auc:0.768443	eval-auc:0.736362
# [272]	train-auc:0.768499	eval-auc:0.736375
# [273]	train-auc:0.76856	eval-auc:0.736416
# [274]	train-auc:0.76856	eval-auc:0.736416
# [275]	train-auc:0.76856	eval-auc:0.736416
# [276]	train-auc:0.768683	eval-auc:0.736359
# [277]	train-auc:0.768805	eval-auc:0.736359
# [278]	train-auc:0.768851	eval-auc:0.736321
# [279]	train-auc:0.768918	eval-auc:0.736317
# [280]	train-auc:0.769021	eval-auc:0.736356
# [281]	train-auc:0.769052	eval-auc:0.736364
# [282]	train-auc:0.769103	eval-auc:0.736355
# [283]	train-auc:0.769137	eval-auc:0.73634
# [284]	train-auc:0.769339	eval-auc:0.736418
# [285]	train-auc:0.769339	eval-auc:0.736418
# [286]	train-auc:0.769377	eval-auc:0.736442
# [287]	train-auc:0.769377	eval-auc:0.736442
# [288]	train-auc:0.769377	eval-auc:0.736442
# [289]	train-auc:0.769377	eval-auc:0.736442
# [290]	train-auc:0.769545	eval-auc:0.736444
# [291]	train-auc:0.769739	eval-auc:0.736485
# [292]	train-auc:0.769826	eval-auc:0.736497
# [293]	train-auc:0.769826	eval-auc:0.736497
# [294]	train-auc:0.769826	eval-auc:0.736497
# [295]	train-auc:0.76989	eval-auc:0.736543
# [296]	train-auc:0.769979	eval-auc:0.736564
# [297]	train-auc:0.769979	eval-auc:0.736564
# [298]	train-auc:0.770138	eval-auc:0.73657
# [299]	train-auc:0.770249	eval-auc:0.736572
# [300]	train-auc:0.770284	eval-auc:0.736544
# [301]	train-auc:0.770312	eval-auc:0.736572
# [302]	train-auc:0.770496	eval-auc:0.736627
# [303]	train-auc:0.77054	eval-auc:0.736619
# [304]	train-auc:0.770607	eval-auc:0.736661
# [305]	train-auc:0.770743	eval-auc:0.736701
# [306]	train-auc:0.770945	eval-auc:0.736723
# [307]	train-auc:0.770945	eval-auc:0.736723
# [308]	train-auc:0.771095	eval-auc:0.736776
# [309]	train-auc:0.771194	eval-auc:0.73681
# [310]	train-auc:0.771194	eval-auc:0.73681
# [311]	train-auc:0.771315	eval-auc:0.736921
# [312]	train-auc:0.771315	eval-auc:0.736921
# [313]	train-auc:0.771374	eval-auc:0.736942
# [314]	train-auc:0.771374	eval-auc:0.736942
# [315]	train-auc:0.77147	eval-auc:0.736958
# [316]	train-auc:0.771531	eval-auc:0.736971
# [317]	train-auc:0.771656	eval-auc:0.736991
# [318]	train-auc:0.771698	eval-auc:0.737043
# [319]	train-auc:0.771698	eval-auc:0.737043
# [320]	train-auc:0.771768	eval-auc:0.737018
# [321]	train-auc:0.771929	eval-auc:0.737065
# [322]	train-auc:0.772001	eval-auc:0.737049
# [323]	train-auc:0.772039	eval-auc:0.737065
# [324]	train-auc:0.772067	eval-auc:0.737064
# [325]	train-auc:0.772067	eval-auc:0.737064
# [326]	train-auc:0.772067	eval-auc:0.737064
# [327]	train-auc:0.772067	eval-auc:0.737064
# [328]	train-auc:0.772124	eval-auc:0.737098
# [329]	train-auc:0.772174	eval-auc:0.73711
# [330]	train-auc:0.772309	eval-auc:0.737119
# [331]	train-auc:0.772309	eval-auc:0.737119
# [332]	train-auc:0.772309	eval-auc:0.737119
# [333]	train-auc:0.772544	eval-auc:0.737091
# [334]	train-auc:0.772626	eval-auc:0.737084
# [335]	train-auc:0.772671	eval-auc:0.73712
# [336]	train-auc:0.772824	eval-auc:0.737121
# [337]	train-auc:0.772962	eval-auc:0.7373
# [338]	train-auc:0.773013	eval-auc:0.737323
# [339]	train-auc:0.77311	eval-auc:0.737319
# [340]	train-auc:0.773223	eval-auc:0.737313
# [341]	train-auc:0.773223	eval-auc:0.737313
# [342]	train-auc:0.773303	eval-auc:0.737351
# [343]	train-auc:0.773303	eval-auc:0.737351
# [344]	train-auc:0.773443	eval-auc:0.737384
# [345]	train-auc:0.773565	eval-auc:0.737483
# [346]	train-auc:0.7737	eval-auc:0.73745
# [347]	train-auc:0.773947	eval-auc:0.737529
# [348]	train-auc:0.774056	eval-auc:0.73754
# [349]	train-auc:0.77415	eval-auc:0.737545
# [350]	train-auc:0.774379	eval-auc:0.737496
# [351]	train-auc:0.774453	eval-auc:0.737493
# [352]	train-auc:0.774453	eval-auc:0.737493
# [353]	train-auc:0.774523	eval-auc:0.737483
# [354]	train-auc:0.77456	eval-auc:0.737471
# [355]	train-auc:0.77469	eval-auc:0.737446
# [356]	train-auc:0.774733	eval-auc:0.737453
# [357]	train-auc:0.774733	eval-auc:0.737453
# [358]	train-auc:0.774802	eval-auc:0.737486
# [359]	train-auc:0.775064	eval-auc:0.73758
# [360]	train-auc:0.775166	eval-auc:0.737572
# [361]	train-auc:0.775166	eval-auc:0.737572
# [362]	train-auc:0.775226	eval-auc:0.737582
# [363]	train-auc:0.775322	eval-auc:0.73758
# [364]	train-auc:0.775403	eval-auc:0.737595
# [365]	train-auc:0.775509	eval-auc:0.737573
# [366]	train-auc:0.77566	eval-auc:0.737538
# [367]	train-auc:0.775805	eval-auc:0.737536
# [368]	train-auc:0.775928	eval-auc:0.737517
# [369]	train-auc:0.776006	eval-auc:0.737513
# [370]	train-auc:0.776006	eval-auc:0.737513
# [371]	train-auc:0.776174	eval-auc:0.737534
# [372]	train-auc:0.7763	eval-auc:0.73754
# [373]	train-auc:0.7763	eval-auc:0.73754
# [374]	train-auc:0.776303	eval-auc:0.737577
# [375]	train-auc:0.776303	eval-auc:0.737577
# [376]	train-auc:0.776303	eval-auc:0.737577
# [377]	train-auc:0.776441	eval-auc:0.73764
# [378]	train-auc:0.776441	eval-auc:0.73764
# [379]	train-auc:0.776494	eval-auc:0.73765
# [380]	train-auc:0.776631	eval-auc:0.737653
# [381]	train-auc:0.776631	eval-auc:0.737653
# [382]	train-auc:0.776631	eval-auc:0.737653
# [383]	train-auc:0.776617	eval-auc:0.737654
# [384]	train-auc:0.776617	eval-auc:0.737654
# [385]	train-auc:0.776617	eval-auc:0.737654
# [386]	train-auc:0.776618	eval-auc:0.737673
# [387]	train-auc:0.776648	eval-auc:0.737669
# [388]	train-auc:0.776751	eval-auc:0.737712
# [389]	train-auc:0.776905	eval-auc:0.737687
# [390]	train-auc:0.776905	eval-auc:0.737687
# [391]	train-auc:0.776996	eval-auc:0.737748
# [392]	train-auc:0.777108	eval-auc:0.737728
# [393]	train-auc:0.777143	eval-auc:0.73773
# [394]	train-auc:0.777196	eval-auc:0.737719
# [395]	train-auc:0.777381	eval-auc:0.737746
# [396]	train-auc:0.777381	eval-auc:0.737746
# [397]	train-auc:0.777457	eval-auc:0.737688
# [398]	train-auc:0.777457	eval-auc:0.737688
# [399]	train-auc:0.777568	eval-auc:0.737676
# [400]	train-auc:0.777648	eval-auc:0.737672
# [401]	train-auc:0.777648	eval-auc:0.737672
# [402]	train-auc:0.777647	eval-auc:0.737672
# [403]	train-auc:0.777782	eval-auc:0.737671
# [404]	train-auc:0.777857	eval-auc:0.737658
# [405]	train-auc:0.777946	eval-auc:0.737653
# [406]	train-auc:0.777946	eval-auc:0.737653
# [407]	train-auc:0.778025	eval-auc:0.737646
# [408]	train-auc:0.778025	eval-auc:0.737646
# [409]	train-auc:0.778144	eval-auc:0.737637
# [410]	train-auc:0.778219	eval-auc:0.737634
# [411]	train-auc:0.778262	eval-auc:0.737639
# [412]	train-auc:0.778377	eval-auc:0.737666
# [413]	train-auc:0.778498	eval-auc:0.737647
# [414]	train-auc:0.778598	eval-auc:0.737721
# [415]	train-auc:0.778642	eval-auc:0.737734
# [416]	train-auc:0.778829	eval-auc:0.737729
# [417]	train-auc:0.778912	eval-auc:0.737732
# [418]	train-auc:0.779086	eval-auc:0.737758
# [419]	train-auc:0.779177	eval-auc:0.737787
# [420]	train-auc:0.779177	eval-auc:0.737787
# [421]	train-auc:0.779328	eval-auc:0.737787
# [422]	train-auc:0.779444	eval-auc:0.737834
# [423]	train-auc:0.779444	eval-auc:0.737834
# [424]	train-auc:0.779618	eval-auc:0.737868
# [425]	train-auc:0.779689	eval-auc:0.737889
# [426]	train-auc:0.779724	eval-auc:0.73792
# [427]	train-auc:0.779751	eval-auc:0.737912
# [428]	train-auc:0.779809	eval-auc:0.737927
# [429]	train-auc:0.77987	eval-auc:0.737935
# [430]	train-auc:0.77987	eval-auc:0.737935
# [431]	train-auc:0.779894	eval-auc:0.737941
# [432]	train-auc:0.780046	eval-auc:0.737933
# [433]	train-auc:0.78018	eval-auc:0.737978
# [434]	train-auc:0.780259	eval-auc:0.737985
# [435]	train-auc:0.780441	eval-auc:0.73806
# [436]	train-auc:0.780441	eval-auc:0.73806
# [437]	train-auc:0.780492	eval-auc:0.738051
# [438]	train-auc:0.780626	eval-auc:0.738005
# [439]	train-auc:0.780665	eval-auc:0.737995
# [440]	train-auc:0.78078	eval-auc:0.738044
# [441]	train-auc:0.780809	eval-auc:0.738025
# [442]	train-auc:0.78091	eval-auc:0.738017
# [443]	train-auc:0.780971	eval-auc:0.73801
# [444]	train-auc:0.780971	eval-auc:0.73801
# [445]	train-auc:0.781062	eval-auc:0.738027
# [446]	train-auc:0.781092	eval-auc:0.738032
# [447]	train-auc:0.781121	eval-auc:0.73805
# [448]	train-auc:0.781176	eval-auc:0.738044
# [449]	train-auc:0.781205	eval-auc:0.738053
# [450]	train-auc:0.781352	eval-auc:0.738038
# [451]	train-auc:0.781352	eval-auc:0.738038
# [452]	train-auc:0.781352	eval-auc:0.738038
# [453]	train-auc:0.781468	eval-auc:0.738039
# [454]	train-auc:0.781588	eval-auc:0.738046
# [455]	train-auc:0.781612	eval-auc:0.738029
# [456]	train-auc:0.781612	eval-auc:0.738029
# [457]	train-auc:0.781666	eval-auc:0.738009
# [458]	train-auc:0.781666	eval-auc:0.738009
# [459]	train-auc:0.781751	eval-auc:0.738002
# [460]	train-auc:0.781804	eval-auc:0.737979
# [461]	train-auc:0.781919	eval-auc:0.737946
# [462]	train-auc:0.781987	eval-auc:0.73794
# [463]	train-auc:0.782061	eval-auc:0.737923
# [464]	train-auc:0.782061	eval-auc:0.737923
# [465]	train-auc:0.782061	eval-auc:0.737923
# [466]	train-auc:0.782151	eval-auc:0.737909
# [467]	train-auc:0.782242	eval-auc:0.737889
# [468]	train-auc:0.782242	eval-auc:0.737889
# [469]	train-auc:0.782242	eval-auc:0.737889
# [470]	train-auc:0.782419	eval-auc:0.737861
# [471]	train-auc:0.7825	eval-auc:0.737899
# [472]	train-auc:0.7825	eval-auc:0.737899
# [473]	train-auc:0.782546	eval-auc:0.737951
# [474]	train-auc:0.782752	eval-auc:0.737956
# [475]	train-auc:0.782785	eval-auc:0.737982
# [476]	train-auc:0.782785	eval-auc:0.737982
# [477]	train-auc:0.782785	eval-auc:0.737982
# [478]	train-auc:0.782969	eval-auc:0.737977
# [479]	train-auc:0.782969	eval-auc:0.737977
# [480]	train-auc:0.783026	eval-auc:0.737982
# [481]	train-auc:0.783111	eval-auc:0.737987
# [482]	train-auc:0.783254	eval-auc:0.737961
# [483]	train-auc:0.783337	eval-auc:0.737958
# [484]	train-auc:0.783415	eval-auc:0.737971
# [485]	train-auc:0.783415	eval-auc:0.737971
# [486]	train-auc:0.783464	eval-auc:0.737992
# [487]	train-auc:0.783482	eval-auc:0.737972
# [488]	train-auc:0.783512	eval-auc:0.738029
# [489]	train-auc:0.783655	eval-auc:0.738019
# [490]	train-auc:0.783751	eval-auc:0.738033
# [491]	train-auc:0.783751	eval-auc:0.738033
# [492]	train-auc:0.783751	eval-auc:0.738033
# [493]	train-auc:0.783839	eval-auc:0.738016
# [494]	train-auc:0.783839	eval-auc:0.738016
# [495]	train-auc:0.783909	eval-auc:0.738039
# [496]	train-auc:0.783958	eval-auc:0.738021
# [497]	train-auc:0.784016	eval-auc:0.738075
# [498]	train-auc:0.784166	eval-auc:0.738069
# [499]	train-auc:0.784371	eval-auc:0.738019
# [500]	train-auc:0.784352	eval-auc:0.738031
# [501]	train-auc:0.784486	eval-auc:0.738058
# [502]	train-auc:0.78456	eval-auc:0.738132
# [503]	train-auc:0.78456	eval-auc:0.738132
# [504]	train-auc:0.78456	eval-auc:0.738132
# [505]	train-auc:0.784594	eval-auc:0.738134
# [506]	train-auc:0.784594	eval-auc:0.738134
# [507]	train-auc:0.784594	eval-auc:0.738157
# [508]	train-auc:0.78472	eval-auc:0.738148
# [509]	train-auc:0.784844	eval-auc:0.738147
# [510]	train-auc:0.784952	eval-auc:0.738132
# [511]	train-auc:0.784997	eval-auc:0.738134
# [512]	train-auc:0.785051	eval-auc:0.738182
# [513]	train-auc:0.785066	eval-auc:0.738185
# [514]	train-auc:0.785066	eval-auc:0.738185
# [515]	train-auc:0.785224	eval-auc:0.738174
# [516]	train-auc:0.785365	eval-auc:0.738211
# [517]	train-auc:0.785445	eval-auc:0.738223
# [518]	train-auc:0.785585	eval-auc:0.73821
# [519]	train-auc:0.785656	eval-auc:0.73819
# [520]	train-auc:0.785669	eval-auc:0.738208
# [521]	train-auc:0.785669	eval-auc:0.738208
# [522]	train-auc:0.785767	eval-auc:0.738198
# [523]	train-auc:0.785915	eval-auc:0.738181
# [524]	train-auc:0.785915	eval-auc:0.738181
# [525]	train-auc:0.785915	eval-auc:0.738181
# [526]	train-auc:0.785985	eval-auc:0.738182
# [527]	train-auc:0.786012	eval-auc:0.738188
# [528]	train-auc:0.786129	eval-auc:0.738244
# [529]	train-auc:0.786161	eval-auc:0.73827
# [530]	train-auc:0.786161	eval-auc:0.73827
# [531]	train-auc:0.786194	eval-auc:0.738269
# [532]	train-auc:0.786283	eval-auc:0.738285
# [533]	train-auc:0.786283	eval-auc:0.738285
# [534]	train-auc:0.786426	eval-auc:0.738253
# [535]	train-auc:0.786426	eval-auc:0.738253
# [536]	train-auc:0.786576	eval-auc:0.73822
# [537]	train-auc:0.786777	eval-auc:0.738285
# [538]	train-auc:0.786823	eval-auc:0.738276
# [539]	train-auc:0.786823	eval-auc:0.738276
# [540]	train-auc:0.786879	eval-auc:0.738291
# [541]	train-auc:0.786965	eval-auc:0.738325
# [542]	train-auc:0.78707	eval-auc:0.738332
# [543]	train-auc:0.787121	eval-auc:0.738317
# [544]	train-auc:0.787164	eval-auc:0.738315
# [545]	train-auc:0.78728	eval-auc:0.738299
# [546]	train-auc:0.78728	eval-auc:0.738299
# [547]	train-auc:0.787299	eval-auc:0.738319
# [548]	train-auc:0.787382	eval-auc:0.738324
# [549]	train-auc:0.787411	eval-auc:0.738309
# [550]	train-auc:0.787444	eval-auc:0.738323
# [551]	train-auc:0.787531	eval-auc:0.738326
# [552]	train-auc:0.787531	eval-auc:0.738326
# [553]	train-auc:0.787701	eval-auc:0.738299
# [554]	train-auc:0.787737	eval-auc:0.738258
# [555]	train-auc:0.787757	eval-auc:0.738259
# [556]	train-auc:0.78787	eval-auc:0.738243
# [557]	train-auc:0.787969	eval-auc:0.738239
# [558]	train-auc:0.787969	eval-auc:0.738239
# [559]	train-auc:0.787969	eval-auc:0.738239
# [560]	train-auc:0.788076	eval-auc:0.738244
# [561]	train-auc:0.788208	eval-auc:0.738254
# [562]	train-auc:0.788257	eval-auc:0.738269
# [563]	train-auc:0.788291	eval-auc:0.738258
# [564]	train-auc:0.788346	eval-auc:0.738275
# [565]	train-auc:0.788475	eval-auc:0.738265
# [566]	train-auc:0.788475	eval-auc:0.738265
# [567]	train-auc:0.788475	eval-auc:0.738265
# [568]	train-auc:0.788475	eval-auc:0.738265
# [569]	train-auc:0.788501	eval-auc:0.738276
# [570]	train-auc:0.788501	eval-auc:0.738276
# [571]	train-auc:0.788577	eval-auc:0.738297
# [572]	train-auc:0.788678	eval-auc:0.738286
# [573]	train-auc:0.78873	eval-auc:0.738287
# [574]	train-auc:0.788848	eval-auc:0.738274
# [575]	train-auc:0.788924	eval-auc:0.738301
# [576]	train-auc:0.789149	eval-auc:0.738343
# [577]	train-auc:0.789269	eval-auc:0.738369
# [578]	train-auc:0.789334	eval-auc:0.738381
# [579]	train-auc:0.789488	eval-auc:0.738388
# [580]	train-auc:0.789524	eval-auc:0.738376
# [581]	train-auc:0.789568	eval-auc:0.738393
# [582]	train-auc:0.789572	eval-auc:0.738414
# [583]	train-auc:0.789649	eval-auc:0.738422
# [584]	train-auc:0.789649	eval-auc:0.738422
# [585]	train-auc:0.789649	eval-auc:0.738422
# [586]	train-auc:0.789649	eval-auc:0.738422
# [587]	train-auc:0.789664	eval-auc:0.738446
# [588]	train-auc:0.789675	eval-auc:0.738429
# [589]	train-auc:0.789675	eval-auc:0.738429
# [590]	train-auc:0.789758	eval-auc:0.738449
# [591]	train-auc:0.789865	eval-auc:0.738439
# [592]	train-auc:0.789865	eval-auc:0.738439
# [593]	train-auc:0.789937	eval-auc:0.738464
# [594]	train-auc:0.790034	eval-auc:0.738442
# [595]	train-auc:0.790034	eval-auc:0.738442
# [596]	train-auc:0.7902	eval-auc:0.738432
# [597]	train-auc:0.7902	eval-auc:0.738432
# [598]	train-auc:0.790278	eval-auc:0.738427
# [599]	train-auc:0.790326	eval-auc:0.738479
# [600]	train-auc:0.79036	eval-auc:0.738481
# [601]	train-auc:0.790449	eval-auc:0.738473
# [602]	train-auc:0.790496	eval-auc:0.738476
# [603]	train-auc:0.790496	eval-auc:0.738476
# [604]	train-auc:0.790521	eval-auc:0.738482
# [605]	train-auc:0.790521	eval-auc:0.738482
# [606]	train-auc:0.790521	eval-auc:0.738482
# [607]	train-auc:0.790521	eval-auc:0.738482
# [608]	train-auc:0.790521	eval-auc:0.738482
# [609]	train-auc:0.790617	eval-auc:0.738503
# [610]	train-auc:0.790755	eval-auc:0.738462
# [611]	train-auc:0.790755	eval-auc:0.738462
# [612]	train-auc:0.790817	eval-auc:0.738501
# [613]	train-auc:0.790817	eval-auc:0.738501
# [614]	train-auc:0.790817	eval-auc:0.738501
# [615]	train-auc:0.790858	eval-auc:0.738503
# [616]	train-auc:0.790896	eval-auc:0.738501
# [617]	train-auc:0.790896	eval-auc:0.738501
# [618]	train-auc:0.790896	eval-auc:0.738501
# [619]	train-auc:0.790896	eval-auc:0.738501
# [620]	train-auc:0.79094	eval-auc:0.738486
# [621]	train-auc:0.79094	eval-auc:0.738486
# [622]	train-auc:0.79094	eval-auc:0.738486
# [623]	train-auc:0.791003	eval-auc:0.738491
# [624]	train-auc:0.791096	eval-auc:0.738508
# [625]	train-auc:0.791096	eval-auc:0.738508
# [626]	train-auc:0.791096	eval-auc:0.738508
# [627]	train-auc:0.791096	eval-auc:0.738508
# [628]	train-auc:0.791192	eval-auc:0.738511
# [629]	train-auc:0.791192	eval-auc:0.738511
# [630]	train-auc:0.791192	eval-auc:0.738511
# [631]	train-auc:0.79123	eval-auc:0.738508
# [632]	train-auc:0.791287	eval-auc:0.738518
# [633]	train-auc:0.791331	eval-auc:0.738518
# [634]	train-auc:0.791444	eval-auc:0.738491
# [635]	train-auc:0.791444	eval-auc:0.738491
# [636]	train-auc:0.791493	eval-auc:0.738492
# [637]	train-auc:0.791597	eval-auc:0.738483
# [638]	train-auc:0.791731	eval-auc:0.738545
# [639]	train-auc:0.791731	eval-auc:0.738545
# [640]	train-auc:0.791866	eval-auc:0.738557
# [641]	train-auc:0.791929	eval-auc:0.738547
# [642]	train-auc:0.792039	eval-auc:0.738535
# [643]	train-auc:0.792039	eval-auc:0.738535
# [644]	train-auc:0.792091	eval-auc:0.738535
# [645]	train-auc:0.79218	eval-auc:0.738558
# [646]	train-auc:0.79218	eval-auc:0.738558
# [647]	train-auc:0.792277	eval-auc:0.73855
# [648]	train-auc:0.792277	eval-auc:0.73855
# [649]	train-auc:0.792277	eval-auc:0.73855
# [650]	train-auc:0.792321	eval-auc:0.738563
# [651]	train-auc:0.792417	eval-auc:0.738605
# [652]	train-auc:0.792417	eval-auc:0.738605
# [653]	train-auc:0.792417	eval-auc:0.738605
# [654]	train-auc:0.792417	eval-auc:0.738605
# [655]	train-auc:0.792559	eval-auc:0.73861
# [656]	train-auc:0.792604	eval-auc:0.738595
# [657]	train-auc:0.792714	eval-auc:0.738606
# [658]	train-auc:0.792714	eval-auc:0.738606
# [659]	train-auc:0.792714	eval-auc:0.738606
# [660]	train-auc:0.792797	eval-auc:0.738635
# [661]	train-auc:0.792797	eval-auc:0.738635
# [662]	train-auc:0.792797	eval-auc:0.738635
# [663]	train-auc:0.792797	eval-auc:0.738635
# [664]	train-auc:0.792894	eval-auc:0.738636
# [665]	train-auc:0.792927	eval-auc:0.738632
# [666]	train-auc:0.792927	eval-auc:0.738632
# [667]	train-auc:0.793104	eval-auc:0.738645
# [668]	train-auc:0.793104	eval-auc:0.738645
# [669]	train-auc:0.793072	eval-auc:0.738652
# [670]	train-auc:0.793114	eval-auc:0.738673
# [671]	train-auc:0.793237	eval-auc:0.73866
# [672]	train-auc:0.793207	eval-auc:0.738659
# [673]	train-auc:0.793324	eval-auc:0.7387
# [674]	train-auc:0.793324	eval-auc:0.7387
# [675]	train-auc:0.793434	eval-auc:0.738658
# [676]	train-auc:0.793518	eval-auc:0.738642
# [677]	train-auc:0.793518	eval-auc:0.738642
# [678]	train-auc:0.793671	eval-auc:0.738594
# [679]	train-auc:0.793671	eval-auc:0.738594
# [680]	train-auc:0.793712	eval-auc:0.738581
# [681]	train-auc:0.793712	eval-auc:0.738581
# [682]	train-auc:0.793807	eval-auc:0.738578
# [683]	train-auc:0.793785	eval-auc:0.738584
# [684]	train-auc:0.793912	eval-auc:0.738579
# [685]	train-auc:0.793912	eval-auc:0.738579
# [686]	train-auc:0.793977	eval-auc:0.738577
# [687]	train-auc:0.794124	eval-auc:0.73858
# [688]	train-auc:0.794124	eval-auc:0.73858
# [689]	train-auc:0.794168	eval-auc:0.738604
# [690]	train-auc:0.794168	eval-auc:0.738604
# [691]	train-auc:0.794168	eval-auc:0.738604
# [692]	train-auc:0.794168	eval-auc:0.738604
# [693]	train-auc:0.794192	eval-auc:0.738611
# [694]	train-auc:0.794278	eval-auc:0.73862
# [695]	train-auc:0.794318	eval-auc:0.738624
# [696]	train-auc:0.794399	eval-auc:0.738648
# [697]	train-auc:0.794399	eval-auc:0.738648
# [698]	train-auc:0.794399	eval-auc:0.738648
# [699]	train-auc:0.794399	eval-auc:0.738648
# [700]	train-auc:0.794399	eval-auc:0.738648
# [701]	train-auc:0.794399	eval-auc:0.738648
# [702]	train-auc:0.794399	eval-auc:0.738648
# [703]	train-auc:0.794399	eval-auc:0.738648
# [704]	train-auc:0.794547	eval-auc:0.738627
# [705]	train-auc:0.794547	eval-auc:0.738627
# [706]	train-auc:0.794547	eval-auc:0.738627
# [707]	train-auc:0.794646	eval-auc:0.738641
# [708]	train-auc:0.794774	eval-auc:0.738743
# [709]	train-auc:0.794774	eval-auc:0.738743
# [710]	train-auc:0.794818	eval-auc:0.738734
# [711]	train-auc:0.794851	eval-auc:0.738736
# [712]	train-auc:0.795181	eval-auc:0.739004
# [713]	train-auc:0.79526	eval-auc:0.738995
# [714]	train-auc:0.795295	eval-auc:0.739029
# [715]	train-auc:0.795295	eval-auc:0.739029
# [716]	train-auc:0.795295	eval-auc:0.739029
# [717]	train-auc:0.795382	eval-auc:0.739019
# [718]	train-auc:0.795382	eval-auc:0.739019
# [719]	train-auc:0.795382	eval-auc:0.739019
# [720]	train-auc:0.795644	eval-auc:0.739212
# [721]	train-auc:0.795644	eval-auc:0.739212
# [722]	train-auc:0.795644	eval-auc:0.739212
# [723]	train-auc:0.795775	eval-auc:0.739243
# [724]	train-auc:0.795775	eval-auc:0.739243
# [725]	train-auc:0.795843	eval-auc:0.739265
# [726]	train-auc:0.795843	eval-auc:0.739265
# [727]	train-auc:0.795843	eval-auc:0.739265
# [728]	train-auc:0.795857	eval-auc:0.739287
# [729]	train-auc:0.795983	eval-auc:0.739254
# [730]	train-auc:0.795983	eval-auc:0.739254
# [731]	train-auc:0.795979	eval-auc:0.739281
# [732]	train-auc:0.796054	eval-auc:0.739287
# [733]	train-auc:0.796054	eval-auc:0.739287
# [734]	train-auc:0.796113	eval-auc:0.739281
# [735]	train-auc:0.796113	eval-auc:0.739281
# [736]	train-auc:0.796128	eval-auc:0.739267
# [737]	train-auc:0.796128	eval-auc:0.739267
# [738]	train-auc:0.796197	eval-auc:0.739261
# [739]	train-auc:0.796197	eval-auc:0.739261
# [740]	train-auc:0.796294	eval-auc:0.739251
# [741]	train-auc:0.796294	eval-auc:0.739251
# [742]	train-auc:0.796272	eval-auc:0.739244
# [743]	train-auc:0.796322	eval-auc:0.739231
# [744]	train-auc:0.796348	eval-auc:0.739211
# [745]	train-auc:0.796374	eval-auc:0.739211
# [746]	train-auc:0.796374	eval-auc:0.739211
# [747]	train-auc:0.796374	eval-auc:0.739211
# [748]	train-auc:0.796477	eval-auc:0.739207
# [749]	train-auc:0.796514	eval-auc:0.739198
# [750]	train-auc:0.79667	eval-auc:0.739195
# [751]	train-auc:0.79667	eval-auc:0.739195
# [752]	train-auc:0.796722	eval-auc:0.7392
# [753]	train-auc:0.796749	eval-auc:0.739179
# [754]	train-auc:0.796749	eval-auc:0.739179
# [755]	train-auc:0.796749	eval-auc:0.739179
# [756]	train-auc:0.796771	eval-auc:0.739178
# [757]	train-auc:0.796771	eval-auc:0.739178
# [758]	train-auc:0.796857	eval-auc:0.739177
# [759]	train-auc:0.796857	eval-auc:0.739177
# [760]	train-auc:0.796857	eval-auc:0.739177
# [761]	train-auc:0.796944	eval-auc:0.739189
# [762]	train-auc:0.796944	eval-auc:0.739189
# [763]	train-auc:0.796944	eval-auc:0.739189
# [764]	train-auc:0.796944	eval-auc:0.739189
# [765]	train-auc:0.796944	eval-auc:0.739189
# [766]	train-auc:0.796944	eval-auc:0.739189
# [767]	train-auc:0.796944	eval-auc:0.739189
# [768]	train-auc:0.796944	eval-auc:0.739189
# [769]	train-auc:0.797079	eval-auc:0.739155
# [770]	train-auc:0.797131	eval-auc:0.739155
# [771]	train-auc:0.797131	eval-auc:0.739155
# [772]	train-auc:0.797131	eval-auc:0.739155
# [773]	train-auc:0.797131	eval-auc:0.739155
# [774]	train-auc:0.797131	eval-auc:0.739155
# [775]	train-auc:0.797131	eval-auc:0.739155
# [776]	train-auc:0.797208	eval-auc:0.73915
# [777]	train-auc:0.797333	eval-auc:0.739122
# [778]	train-auc:0.797333	eval-auc:0.739122
# [779]	train-auc:0.797395	eval-auc:0.739148
# [780]	train-auc:0.797435	eval-auc:0.739144
# [781]	train-auc:0.797435	eval-auc:0.739144
# [782]	train-auc:0.797435	eval-auc:0.739144
# [783]	train-auc:0.79755	eval-auc:0.739124
# [784]	train-auc:0.79755	eval-auc:0.739124
# [785]	train-auc:0.797639	eval-auc:0.739133
# [786]	train-auc:0.797639	eval-auc:0.739133
# [787]	train-auc:0.797826	eval-auc:0.73911
# [788]	train-auc:0.797826	eval-auc:0.73911
# [789]	train-auc:0.797826	eval-auc:0.73911
# [790]	train-auc:0.797826	eval-auc:0.73911
# [791]	train-auc:0.797826	eval-auc:0.73911
# [792]	train-auc:0.79791	eval-auc:0.73911
# [793]	train-auc:0.797968	eval-auc:0.739115
# [794]	train-auc:0.798092	eval-auc:0.739089
# [795]	train-auc:0.798092	eval-auc:0.739089
# [796]	train-auc:0.798162	eval-auc:0.739098
# [797]	train-auc:0.798228	eval-auc:0.739074
# [798]	train-auc:0.798289	eval-auc:0.739096
# [799]	train-auc:0.798385	eval-auc:0.739083
# [800]	train-auc:0.798424	eval-auc:0.739097
# [801]	train-auc:0.798462	eval-auc:0.739103
# [802]	train-auc:0.798499	eval-auc:0.739078
# [803]	train-auc:0.798499	eval-auc:0.739078
# [804]	train-auc:0.798499	eval-auc:0.739078
# [805]	train-auc:0.798548	eval-auc:0.739055
# [806]	train-auc:0.798548	eval-auc:0.739055
# [807]	train-auc:0.79863	eval-auc:0.73905
# [808]	train-auc:0.79863	eval-auc:0.73905
# [809]	train-auc:0.79871	eval-auc:0.739044
# [810]	train-auc:0.798862	eval-auc:0.739034
# [811]	train-auc:0.798927	eval-auc:0.739057
# [812]	train-auc:0.798927	eval-auc:0.739057
# [813]	train-auc:0.79902	eval-auc:0.739036
# [814]	train-auc:0.79902	eval-auc:0.739036
# [815]	train-auc:0.799084	eval-auc:0.739015
# [816]	train-auc:0.79913	eval-auc:0.739009
# [817]	train-auc:0.799248	eval-auc:0.738951
# [818]	train-auc:0.799248	eval-auc:0.738951
# [819]	train-auc:0.799244	eval-auc:0.738944
# [820]	train-auc:0.799244	eval-auc:0.738944
# [821]	train-auc:0.799244	eval-auc:0.738944
# [822]	train-auc:0.799244	eval-auc:0.738944
# [823]	train-auc:0.799318	eval-auc:0.738961
# [824]	train-auc:0.799488	eval-auc:0.739097
# [825]	train-auc:0.799535	eval-auc:0.739094
# [826]	train-auc:0.799535	eval-auc:0.739094
# [827]	train-auc:0.799535	eval-auc:0.739094
# [828]	train-auc:0.799565	eval-auc:0.739098
# [829]	train-auc:0.799565	eval-auc:0.739098
# [830]	train-auc:0.799636	eval-auc:0.739103
# [831]	train-auc:0.799636	eval-auc:0.739103
# [832]	train-auc:0.799655	eval-auc:0.739149
# [833]	train-auc:0.799737	eval-auc:0.739127
# [834]	train-auc:0.799737	eval-auc:0.739127
# [835]	train-auc:0.799737	eval-auc:0.739127
# [836]	train-auc:0.799737	eval-auc:0.739127
# [837]	train-auc:0.799737	eval-auc:0.739127
# [838]	train-auc:0.79977	eval-auc:0.739124
# [839]	train-auc:0.799798	eval-auc:0.73912
# [840]	train-auc:0.799833	eval-auc:0.739139
# [841]	train-auc:0.799833	eval-auc:0.739139
# [842]	train-auc:0.799852	eval-auc:0.739174
# [843]	train-auc:0.799852	eval-auc:0.739174
# [844]	train-auc:0.79993	eval-auc:0.739181
# [845]	train-auc:0.800001	eval-auc:0.739171
# [846]	train-auc:0.800178	eval-auc:0.739163
# [847]	train-auc:0.800236	eval-auc:0.739128
# [848]	train-auc:0.800236	eval-auc:0.739128
# [849]	train-auc:0.800281	eval-auc:0.739101
# [850]	train-auc:0.800281	eval-auc:0.739101
# [851]	train-auc:0.800281	eval-auc:0.739101
# [852]	train-auc:0.800308	eval-auc:0.739116
# [853]	train-auc:0.800308	eval-auc:0.739116
# [854]	train-auc:0.800332	eval-auc:0.739125
# [855]	train-auc:0.800358	eval-auc:0.739123
# [856]	train-auc:0.800358	eval-auc:0.739123
# [857]	train-auc:0.800379	eval-auc:0.739116
# [858]	train-auc:0.800439	eval-auc:0.739155
# [859]	train-auc:0.800439	eval-auc:0.739155
# [860]	train-auc:0.800531	eval-auc:0.739164
# [861]	train-auc:0.800597	eval-auc:0.73917
# [862]	train-auc:0.800597	eval-auc:0.73917
# [863]	train-auc:0.800597	eval-auc:0.73917
# [864]	train-auc:0.800669	eval-auc:0.739155
# [865]	train-auc:0.800712	eval-auc:0.739141
# [866]	train-auc:0.800712	eval-auc:0.739141
# [867]	train-auc:0.800712	eval-auc:0.739141
# [868]	train-auc:0.800712	eval-auc:0.739141
# [869]	train-auc:0.800755	eval-auc:0.73913
# [870]	train-auc:0.800755	eval-auc:0.73913
# [871]	train-auc:0.800755	eval-auc:0.73913
# [872]	train-auc:0.800793	eval-auc:0.739119
# [873]	train-auc:0.800827	eval-auc:0.739127
# [874]	train-auc:0.800862	eval-auc:0.739115
# [875]	train-auc:0.800862	eval-auc:0.739115
# [876]	train-auc:0.800862	eval-auc:0.739115
# [877]	train-auc:0.800901	eval-auc:0.739117
# [878]	train-auc:0.800959	eval-auc:0.739116
# [879]	train-auc:0.800959	eval-auc:0.739116
# [880]	train-auc:0.800992	eval-auc:0.739115
# [881]	train-auc:0.800992	eval-auc:0.739115
# [882]	train-auc:0.80106	eval-auc:0.739107
# [883]	train-auc:0.80106	eval-auc:0.739107
# [884]	train-auc:0.801137	eval-auc:0.739112
# [885]	train-auc:0.801137	eval-auc:0.739112
# [886]	train-auc:0.801137	eval-auc:0.739112
# [887]	train-auc:0.801158	eval-auc:0.739083
# [888]	train-auc:0.801158	eval-auc:0.739083
# [889]	train-auc:0.801158	eval-auc:0.739083
# [890]	train-auc:0.801158	eval-auc:0.739083
# [891]	train-auc:0.801157	eval-auc:0.73908
# [892]	train-auc:0.801157	eval-auc:0.73908
# [893]	train-auc:0.801244	eval-auc:0.739097
# [894]	train-auc:0.801299	eval-auc:0.739085
# [895]	train-auc:0.801427	eval-auc:0.7391
# [896]	train-auc:0.801548	eval-auc:0.739086
# [897]	train-auc:0.801577	eval-auc:0.739102
# [898]	train-auc:0.801634	eval-auc:0.739082
# [899]	train-auc:0.801652	eval-auc:0.739089
# [900]	train-auc:0.801746	eval-auc:0.739098
# [901]	train-auc:0.801857	eval-auc:0.739125
# [902]	train-auc:0.801857	eval-auc:0.739125
# [903]	train-auc:0.801857	eval-auc:0.739125
# [904]	train-auc:0.801857	eval-auc:0.739125
# [905]	train-auc:0.801857	eval-auc:0.739125
# [906]	train-auc:0.801857	eval-auc:0.739125
# [907]	train-auc:0.801901	eval-auc:0.739114
# [908]	train-auc:0.801901	eval-auc:0.739114
# [909]	train-auc:0.801901	eval-auc:0.739114
# [910]	train-auc:0.801901	eval-auc:0.739114
# [911]	train-auc:0.801901	eval-auc:0.739114
# [912]	train-auc:0.801901	eval-auc:0.739114
# [913]	train-auc:0.802017	eval-auc:0.739106
# [914]	train-auc:0.802089	eval-auc:0.739136
# [915]	train-auc:0.802128	eval-auc:0.739124
# [916]	train-auc:0.802176	eval-auc:0.739147
# [917]	train-auc:0.802259	eval-auc:0.739146
# [918]	train-auc:0.80231	eval-auc:0.739144
# [919]	train-auc:0.802389	eval-auc:0.739131
# [920]	train-auc:0.802414	eval-auc:0.739117
# [921]	train-auc:0.802455	eval-auc:0.739115
# [922]	train-auc:0.802455	eval-auc:0.739115
# [923]	train-auc:0.802455	eval-auc:0.739115
# [924]	train-auc:0.802572	eval-auc:0.739058
# [925]	train-auc:0.802572	eval-auc:0.739058
# [926]	train-auc:0.802572	eval-auc:0.739058
# [927]	train-auc:0.802656	eval-auc:0.739055
# [928]	train-auc:0.802656	eval-auc:0.739055
# [929]	train-auc:0.802656	eval-auc:0.739055
# [930]	train-auc:0.802797	eval-auc:0.739085
# [931]	train-auc:0.802898	eval-auc:0.73907
# [932]	train-auc:0.802898	eval-auc:0.73907
# [933]	train-auc:0.802898	eval-auc:0.73907
# [934]	train-auc:0.802925	eval-auc:0.739066
# [935]	train-auc:0.802925	eval-auc:0.739066
# [936]	train-auc:0.803072	eval-auc:0.739044
# [937]	train-auc:0.803114	eval-auc:0.739046
# [938]	train-auc:0.803114	eval-auc:0.739046
# [939]	train-auc:0.803249	eval-auc:0.739045
# [940]	train-auc:0.803266	eval-auc:0.739032
# [941]	train-auc:0.803266	eval-auc:0.739032
# [942]	train-auc:0.803266	eval-auc:0.739032
# [943]	train-auc:0.803308	eval-auc:0.739
# [944]	train-auc:0.803308	eval-auc:0.739
# [945]	train-auc:0.803308	eval-auc:0.739
# [946]	train-auc:0.803376	eval-auc:0.738979
# [947]	train-auc:0.803399	eval-auc:0.738982
# [948]	train-auc:0.803445	eval-auc:0.738956
# [949]	train-auc:0.803445	eval-auc:0.738956
# [950]	train-auc:0.803445	eval-auc:0.738956
# [951]	train-auc:0.803473	eval-auc:0.738965
# [952]	train-auc:0.803521	eval-auc:0.73898
# [953]	train-auc:0.803607	eval-auc:0.738968
# [954]	train-auc:0.803607	eval-auc:0.738968
# [955]	train-auc:0.803607	eval-auc:0.738968
# [956]	train-auc:0.803607	eval-auc:0.738968
# [957]	train-auc:0.803681	eval-auc:0.738981
# [958]	train-auc:0.803681	eval-auc:0.738981
# [959]	train-auc:0.803681	eval-auc:0.738981
# [960]	train-auc:0.803732	eval-auc:0.738979
# [961]	train-auc:0.803805	eval-auc:0.738961
# [962]	train-auc:0.803805	eval-auc:0.738961
# [963]	train-auc:0.803876	eval-auc:0.738943
# [964]	train-auc:0.803876	eval-auc:0.738943
# [965]	train-auc:0.803902	eval-auc:0.738932
# [966]	train-auc:0.803975	eval-auc:0.738907
# [967]	train-auc:0.803975	eval-auc:0.738907
# [968]	train-auc:0.804111	eval-auc:0.738922
# [969]	train-auc:0.804111	eval-auc:0.738922
# [970]	train-auc:0.804178	eval-auc:0.738928
# [971]	train-auc:0.804178	eval-auc:0.738928
# [972]	train-auc:0.804282	eval-auc:0.738916
# [973]	train-auc:0.804357	eval-auc:0.738894
# [974]	train-auc:0.80438	eval-auc:0.738879
# [975]	train-auc:0.804386	eval-auc:0.738876
# [976]	train-auc:0.804421	eval-auc:0.738886
# [977]	train-auc:0.804458	eval-auc:0.738879
# [978]	train-auc:0.804458	eval-auc:0.738879
# [979]	train-auc:0.804539	eval-auc:0.738864
# [980]	train-auc:0.804661	eval-auc:0.738873
# [981]	train-auc:0.804709	eval-auc:0.738877
# [982]	train-auc:0.804709	eval-auc:0.738877
# [983]	train-auc:0.804709	eval-auc:0.738877
# [984]	train-auc:0.804709	eval-auc:0.738877
# [985]	train-auc:0.8048	eval-auc:0.738933
# [986]	train-auc:0.8048	eval-auc:0.738933
# [987]	train-auc:0.8048	eval-auc:0.738933
# [988]	train-auc:0.8048	eval-auc:0.738933
# [989]	train-auc:0.8048	eval-auc:0.738933
# [990]	train-auc:0.8048	eval-auc:0.738933
# [991]	train-auc:0.8048	eval-auc:0.738933
# [992]	train-auc:0.8048	eval-auc:0.738933
# [993]	train-auc:0.804871	eval-auc:0.738941
# [994]	train-auc:0.804887	eval-auc:0.738926
# [995]	train-auc:0.804914	eval-auc:0.73891
# [996]	train-auc:0.80496	eval-auc:0.738905
# [997]	train-auc:0.80496	eval-auc:0.738905
# [998]	train-auc:0.80496	eval-auc:0.738905
# [999]	train-auc:0.804996	eval-auc:0.738903
# /Users/syamantak/.pyenv/versions/3.7.0/lib/python3.7/site-packages/numpy/lib/function_base.py:356: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /Users/syamantak/.pyenv/versions/3.7.0/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ===Processing fold 1===
# 1.0    28338
# 0.0    28338
# Name: label, dtype: int64
# [0]	train-auc:0.663099	eval-auc:0.659159
# [1]	train-auc:0.674307	eval-auc:0.669424
# [2]	train-auc:0.679268	eval-auc:0.673742
# [3]	train-auc:0.680974	eval-auc:0.675379
# [4]	train-auc:0.684678	eval-auc:0.679274
# [5]	train-auc:0.691197	eval-auc:0.685368
# [6]	train-auc:0.692652	eval-auc:0.686714
# [7]	train-auc:0.696095	eval-auc:0.689903
# [8]	train-auc:0.697454	eval-auc:0.69139
# [9]	train-auc:0.698172	eval-auc:0.69212
# [10]	train-auc:0.700192	eval-auc:0.693995
# [11]	train-auc:0.700962	eval-auc:0.695226
# [12]	train-auc:0.702949	eval-auc:0.696812
# [13]	train-auc:0.703281	eval-auc:0.696943
# [14]	train-auc:0.704864	eval-auc:0.698442
# [15]	train-auc:0.705259	eval-auc:0.698888
# [16]	train-auc:0.705909	eval-auc:0.699183
# [17]	train-auc:0.706834	eval-auc:0.699654
# [18]	train-auc:0.708124	eval-auc:0.701135
# [19]	train-auc:0.709619	eval-auc:0.702643
# [20]	train-auc:0.710882	eval-auc:0.703533
# [21]	train-auc:0.711559	eval-auc:0.703991
# [22]	train-auc:0.712416	eval-auc:0.704749
# [23]	train-auc:0.712879	eval-auc:0.705247
# [24]	train-auc:0.713743	eval-auc:0.705825
# [25]	train-auc:0.714294	eval-auc:0.706221
# [26]	train-auc:0.714731	eval-auc:0.706547
# [27]	train-auc:0.715246	eval-auc:0.70697
# [28]	train-auc:0.716305	eval-auc:0.707676
# [29]	train-auc:0.716756	eval-auc:0.708088
# [30]	train-auc:0.717989	eval-auc:0.709323
# [31]	train-auc:0.718731	eval-auc:0.710019
# [32]	train-auc:0.719917	eval-auc:0.710815
# [33]	train-auc:0.720327	eval-auc:0.711136
# [34]	train-auc:0.720344	eval-auc:0.711134
# [35]	train-auc:0.72098	eval-auc:0.711486
# [36]	train-auc:0.721642	eval-auc:0.711931
# [37]	train-auc:0.722778	eval-auc:0.713072
# [38]	train-auc:0.723171	eval-auc:0.713478
# [39]	train-auc:0.723528	eval-auc:0.7137
# [40]	train-auc:0.724032	eval-auc:0.714107
# [41]	train-auc:0.725019	eval-auc:0.714855
# [42]	train-auc:0.725601	eval-auc:0.715269
# [43]	train-auc:0.726205	eval-auc:0.715712
# [44]	train-auc:0.726887	eval-auc:0.716228
# [45]	train-auc:0.72752	eval-auc:0.716574
# [46]	train-auc:0.728032	eval-auc:0.71696
# [47]	train-auc:0.728868	eval-auc:0.717631
# [48]	train-auc:0.729218	eval-auc:0.717837
# [49]	train-auc:0.729663	eval-auc:0.718241
# [50]	train-auc:0.729989	eval-auc:0.718567
# [51]	train-auc:0.730686	eval-auc:0.719007
# [52]	train-auc:0.730991	eval-auc:0.719336
# [53]	train-auc:0.731219	eval-auc:0.719464
# [54]	train-auc:0.731648	eval-auc:0.719755
# [55]	train-auc:0.732051	eval-auc:0.719961
# [56]	train-auc:0.732302	eval-auc:0.720169
# [57]	train-auc:0.732575	eval-auc:0.720419
# [58]	train-auc:0.732865	eval-auc:0.720674
# [59]	train-auc:0.733046	eval-auc:0.72085
# [60]	train-auc:0.733501	eval-auc:0.721027
# [61]	train-auc:0.734234	eval-auc:0.721589
# [62]	train-auc:0.734715	eval-auc:0.721797
# [63]	train-auc:0.735022	eval-auc:0.722126
# [64]	train-auc:0.735411	eval-auc:0.722248
# [65]	train-auc:0.735789	eval-auc:0.72244
# [66]	train-auc:0.736086	eval-auc:0.72266
# [67]	train-auc:0.736537	eval-auc:0.723087
# [68]	train-auc:0.736763	eval-auc:0.723211
# [69]	train-auc:0.737269	eval-auc:0.723614
# [70]	train-auc:0.737522	eval-auc:0.723781
# [71]	train-auc:0.737957	eval-auc:0.72403
# [72]	train-auc:0.738436	eval-auc:0.72438
# [73]	train-auc:0.738576	eval-auc:0.72444
# [74]	train-auc:0.739098	eval-auc:0.724805
# [75]	train-auc:0.739411	eval-auc:0.724917
# [76]	train-auc:0.739531	eval-auc:0.724965
# [77]	train-auc:0.739878	eval-auc:0.725145
# [78]	train-auc:0.740258	eval-auc:0.72537
# [79]	train-auc:0.740756	eval-auc:0.725749
# [80]	train-auc:0.74105	eval-auc:0.725809
# [81]	train-auc:0.741376	eval-auc:0.725978
# [82]	train-auc:0.74176	eval-auc:0.726076
# [83]	train-auc:0.741981	eval-auc:0.726184
# [84]	train-auc:0.74223	eval-auc:0.726384
# [85]	train-auc:0.742667	eval-auc:0.726667
# [86]	train-auc:0.742825	eval-auc:0.726765
# [87]	train-auc:0.742943	eval-auc:0.726868
# [88]	train-auc:0.743307	eval-auc:0.727053
# [89]	train-auc:0.743645	eval-auc:0.727284
# [90]	train-auc:0.743934	eval-auc:0.727503
# [91]	train-auc:0.744259	eval-auc:0.727697
# [92]	train-auc:0.744342	eval-auc:0.727687
# [93]	train-auc:0.744446	eval-auc:0.727732
# [94]	train-auc:0.744954	eval-auc:0.727956
# [95]	train-auc:0.745201	eval-auc:0.728159
# [96]	train-auc:0.745441	eval-auc:0.728218
# [97]	train-auc:0.745703	eval-auc:0.728287
# [98]	train-auc:0.746064	eval-auc:0.728529
# [99]	train-auc:0.746268	eval-auc:0.728686
# [100]	train-auc:0.746557	eval-auc:0.728723
# [101]	train-auc:0.746877	eval-auc:0.728948
# [102]	train-auc:0.747161	eval-auc:0.72899
# [103]	train-auc:0.747417	eval-auc:0.729107
# [104]	train-auc:0.747603	eval-auc:0.729194
# [105]	train-auc:0.747817	eval-auc:0.72928
# [106]	train-auc:0.747957	eval-auc:0.729329
# [107]	train-auc:0.748291	eval-auc:0.729513
# [108]	train-auc:0.748376	eval-auc:0.729583
# [109]	train-auc:0.748446	eval-auc:0.729598
# [110]	train-auc:0.748617	eval-auc:0.729647
# [111]	train-auc:0.748802	eval-auc:0.729724
# [112]	train-auc:0.749059	eval-auc:0.729817
# [113]	train-auc:0.749171	eval-auc:0.729848
# [114]	train-auc:0.749374	eval-auc:0.729889
# ...
# [640]	train-auc:0.792962	eval-auc:0.737903
# [641]	train-auc:0.793011	eval-auc:0.737897
# [642]	train-auc:0.793183	eval-auc:0.737884
# [643]	train-auc:0.79325	eval-auc:0.737905
# [644]	train-auc:0.793301	eval-auc:0.737925
# [645]	train-auc:0.793401	eval-auc:0.737936
# [646]	train-auc:0.793472	eval-auc:0.73796
# [647]	train-auc:0.793582	eval-auc:0.737885
# [648]	train-auc:0.793618	eval-auc:0.737884
# [649]	train-auc:0.793726	eval-auc:0.737884
# [650]	train-auc:0.793726	eval-auc:0.737884
# [651]	train-auc:0.793756	eval-auc:0.737877
# [652]	train-auc:0.793756	eval-auc:0.737877
# [653]	train-auc:0.793756	eval-auc:0.737877
# [654]	train-auc:0.793756	eval-auc:0.737877
# [655]	train-auc:0.793756	eval-auc:0.737877
# [656]	train-auc:0.793883	eval-auc:0.737903
# [657]	train-auc:0.793883	eval-auc:0.737903
# [658]	train-auc:0.793951	eval-auc:0.737908
# [659]	train-auc:0.793951	eval-auc:0.737908
# [660]	train-auc:0.793979	eval-auc:0.737919
# [661]	train-auc:0.793979	eval-auc:0.737919
# [662]	train-auc:0.794021	eval-auc:0.737921
# [663]	train-auc:0.794135	eval-auc:0.737921
# [664]	train-auc:0.794135	eval-auc:0.737921
# [665]	train-auc:0.794135	eval-auc:0.737921
# [666]	train-auc:0.794223	eval-auc:0.737928
# [667]	train-auc:0.794363	eval-auc:0.738018
# [668]	train-auc:0.794423	eval-auc:0.737984
# [669]	train-auc:0.794423	eval-auc:0.737984
# [670]	train-auc:0.794487	eval-auc:0.73799
# [671]	train-auc:0.794487	eval-auc:0.73799
# [672]	train-auc:0.794632	eval-auc:0.737991
# [673]	train-auc:0.794692	eval-auc:0.738009
# [674]	train-auc:0.794701	eval-auc:0.738
# [675]	train-auc:0.794701	eval-auc:0.738
# [676]	train-auc:0.794711	eval-auc:0.738007
# [677]	train-auc:0.794711	eval-auc:0.738007
# [678]	train-auc:0.794711	eval-auc:0.738007
# [679]	train-auc:0.794835	eval-auc:0.738014
# [680]	train-auc:0.794922	eval-auc:0.73802
# [681]	train-auc:0.794922	eval-auc:0.73802
# [682]	train-auc:0.794951	eval-auc:0.73801
# [683]	train-auc:0.79503	eval-auc:0.737976
# [684]	train-auc:0.795059	eval-auc:0.73801
# [685]	train-auc:0.795099	eval-auc:0.737998
# [686]	train-auc:0.795166	eval-auc:0.737989
# [687]	train-auc:0.795166	eval-auc:0.737989
# [688]	train-auc:0.795166	eval-auc:0.737989
# [689]	train-auc:0.795166	eval-auc:0.737989
# [690]	train-auc:0.795216	eval-auc:0.737994
# [691]	train-auc:0.795216	eval-auc:0.737994
# [692]	train-auc:0.79529	eval-auc:0.737986
# [693]	train-auc:0.795452	eval-auc:0.737994
# [694]	train-auc:0.795452	eval-auc:0.737994
# [695]	train-auc:0.795549	eval-auc:0.738018
# [696]	train-auc:0.795601	eval-auc:0.738027
# [697]	train-auc:0.795643	eval-auc:0.73803
# [698]	train-auc:0.795709	eval-auc:0.738038
# [699]	train-auc:0.795786	eval-auc:0.738056
# [700]	train-auc:0.795786	eval-auc:0.738056
# [701]	train-auc:0.795891	eval-auc:0.738068
# [702]	train-auc:0.79594	eval-auc:0.738066
# [703]	train-auc:0.79594	eval-auc:0.738066
# [704]	train-auc:0.795997	eval-auc:0.738078
# [705]	train-auc:0.796018	eval-auc:0.738069
# [706]	train-auc:0.796168	eval-auc:0.738078
# [707]	train-auc:0.79622	eval-auc:0.738079
# [708]	train-auc:0.796314	eval-auc:0.738055
# [709]	train-auc:0.796314	eval-auc:0.738055
# [710]	train-auc:0.796314	eval-auc:0.738055
# [711]	train-auc:0.796314	eval-auc:0.738055
# [712]	train-auc:0.796389	eval-auc:0.738058
# [713]	train-auc:0.796382	eval-auc:0.738048
# [714]	train-auc:0.796411	eval-auc:0.738083
# [715]	train-auc:0.796454	eval-auc:0.738084
# [716]	train-auc:0.796459	eval-auc:0.738071
# [717]	train-auc:0.79651	eval-auc:0.738073
# [718]	train-auc:0.79651	eval-auc:0.738073
# [719]	train-auc:0.796677	eval-auc:0.73807
# [720]	train-auc:0.796677	eval-auc:0.73807
# [721]	train-auc:0.796681	eval-auc:0.738072
# [722]	train-auc:0.796738	eval-auc:0.738091
# [723]	train-auc:0.796788	eval-auc:0.738151
# [724]	train-auc:0.796788	eval-auc:0.738151
# [725]	train-auc:0.797002	eval-auc:0.738172
# [726]	train-auc:0.797002	eval-auc:0.738172
# [727]	train-auc:0.797072	eval-auc:0.738137
# [728]	train-auc:0.797072	eval-auc:0.738137
# [729]	train-auc:0.797104	eval-auc:0.738124
# [730]	train-auc:0.797104	eval-auc:0.738124
# [731]	train-auc:0.797104	eval-auc:0.738124
# [732]	train-auc:0.797149	eval-auc:0.738139
# [733]	train-auc:0.797187	eval-auc:0.738142
# [734]	train-auc:0.797215	eval-auc:0.73814
# [735]	train-auc:0.797481	eval-auc:0.738279
# [736]	train-auc:0.797546	eval-auc:0.738283
# [737]	train-auc:0.797546	eval-auc:0.738283
# [738]	train-auc:0.797546	eval-auc:0.738283
# [739]	train-auc:0.797546	eval-auc:0.738283
# [740]	train-auc:0.7976	eval-auc:0.738289
# [741]	train-auc:0.797647	eval-auc:0.738304
# [742]	train-auc:0.797679	eval-auc:0.738328
# [743]	train-auc:0.797679	eval-auc:0.738328
# [744]	train-auc:0.797679	eval-auc:0.738328
# [745]	train-auc:0.797679	eval-auc:0.738328
# [746]	train-auc:0.797699	eval-auc:0.738336
# [747]	train-auc:0.797814	eval-auc:0.738323
# [748]	train-auc:0.797814	eval-auc:0.738323
# [749]	train-auc:0.797853	eval-auc:0.738332
# [750]	train-auc:0.797899	eval-auc:0.738334
# [751]	train-auc:0.797961	eval-auc:0.738339
# [752]	train-auc:0.798032	eval-auc:0.738368
# [753]	train-auc:0.798032	eval-auc:0.738368
# [754]	train-auc:0.798032	eval-auc:0.738368
# [755]	train-auc:0.798074	eval-auc:0.738357
# [756]	train-auc:0.798074	eval-auc:0.738357
# [757]	train-auc:0.798074	eval-auc:0.738357
# [758]	train-auc:0.798147	eval-auc:0.738355
# [759]	train-auc:0.798252	eval-auc:0.738359
# [760]	train-auc:0.798252	eval-auc:0.738359
# [761]	train-auc:0.798252	eval-auc:0.738359
# [762]	train-auc:0.798346	eval-auc:0.738365
# [763]	train-auc:0.798346	eval-auc:0.738365
# [764]	train-auc:0.798346	eval-auc:0.738365
# [765]	train-auc:0.798355	eval-auc:0.738367
# [766]	train-auc:0.798355	eval-auc:0.738367
# [767]	train-auc:0.798394	eval-auc:0.73837
# [768]	train-auc:0.798514	eval-auc:0.738361
# [769]	train-auc:0.798562	eval-auc:0.738376
# [770]	train-auc:0.798612	eval-auc:0.738346
# [771]	train-auc:0.798673	eval-auc:0.738334
# [772]	train-auc:0.79879	eval-auc:0.738317
# [773]	train-auc:0.798844	eval-auc:0.738315
# [774]	train-auc:0.798897	eval-auc:0.738297
# [775]	train-auc:0.798897	eval-auc:0.738297
# [776]	train-auc:0.799045	eval-auc:0.738283
# [777]	train-auc:0.799067	eval-auc:0.738271
# [778]	train-auc:0.799111	eval-auc:0.738259
# [779]	train-auc:0.799111	eval-auc:0.738259
# [780]	train-auc:0.799219	eval-auc:0.738264
# [781]	train-auc:0.799219	eval-auc:0.738264
# [782]	train-auc:0.799241	eval-auc:0.738269
# [783]	train-auc:0.799261	eval-auc:0.738261
# [784]	train-auc:0.799261	eval-auc:0.738261
# [785]	train-auc:0.799379	eval-auc:0.738269
# [786]	train-auc:0.799379	eval-auc:0.738269
# [787]	train-auc:0.799379	eval-auc:0.738269
# [788]	train-auc:0.799379	eval-auc:0.738269
# [789]	train-auc:0.799523	eval-auc:0.738262
# [790]	train-auc:0.799523	eval-auc:0.738262
# [791]	train-auc:0.799523	eval-auc:0.738262
# [792]	train-auc:0.799583	eval-auc:0.738261
# [793]	train-auc:0.799583	eval-auc:0.738261
# [794]	train-auc:0.799583	eval-auc:0.738261
# [795]	train-auc:0.799583	eval-auc:0.738261
# [796]	train-auc:0.799583	eval-auc:0.738261
# [797]	train-auc:0.799583	eval-auc:0.738261
# [798]	train-auc:0.799742	eval-auc:0.738278
# [799]	train-auc:0.799796	eval-auc:0.738273
# [800]	train-auc:0.79981	eval-auc:0.738266
# [801]	train-auc:0.79981	eval-auc:0.738266
# [802]	train-auc:0.799833	eval-auc:0.738305
# [803]	train-auc:0.799833	eval-auc:0.738305
# [804]	train-auc:0.799833	eval-auc:0.738305
# [805]	train-auc:0.800005	eval-auc:0.738286
# [806]	train-auc:0.800132	eval-auc:0.738268
# [807]	train-auc:0.800132	eval-auc:0.738268
# [808]	train-auc:0.80016	eval-auc:0.738271
# [809]	train-auc:0.80016	eval-auc:0.738271
# [810]	train-auc:0.80016	eval-auc:0.738271
# [811]	train-auc:0.800164	eval-auc:0.738277
# [812]	train-auc:0.800164	eval-auc:0.738277
# [813]	train-auc:0.800251	eval-auc:0.738262
# [814]	train-auc:0.800251	eval-auc:0.738262
# [815]	train-auc:0.800251	eval-auc:0.738262
# [816]	train-auc:0.800322	eval-auc:0.738299
# [817]	train-auc:0.800386	eval-auc:0.738276
# [818]	train-auc:0.800386	eval-auc:0.738276
# [819]	train-auc:0.800386	eval-auc:0.738276
# [820]	train-auc:0.800386	eval-auc:0.738276
# [821]	train-auc:0.800386	eval-auc:0.738276
# [822]	train-auc:0.800485	eval-auc:0.738307
# [823]	train-auc:0.800485	eval-auc:0.738307
# [824]	train-auc:0.800529	eval-auc:0.738302
# [825]	train-auc:0.800529	eval-auc:0.738302
# [826]	train-auc:0.800632	eval-auc:0.738345
# [827]	train-auc:0.800678	eval-auc:0.738343
# [828]	train-auc:0.800678	eval-auc:0.738343
# [829]	train-auc:0.800678	eval-auc:0.738343
# [830]	train-auc:0.800678	eval-auc:0.738343
# [831]	train-auc:0.800678	eval-auc:0.738343
# [832]	train-auc:0.800678	eval-auc:0.738343
# [833]	train-auc:0.8007	eval-auc:0.738335
# [834]	train-auc:0.8007	eval-auc:0.738335
# [835]	train-auc:0.8007	eval-auc:0.738335
# [836]	train-auc:0.800789	eval-auc:0.738387
# [837]	train-auc:0.800789	eval-auc:0.738387
# [838]	train-auc:0.800789	eval-auc:0.738387
# [839]	train-auc:0.800789	eval-auc:0.738387
# [840]	train-auc:0.800789	eval-auc:0.738387
# [841]	train-auc:0.800789	eval-auc:0.738387
# [842]	train-auc:0.800789	eval-auc:0.738387
# [843]	train-auc:0.800789	eval-auc:0.738387
# [844]	train-auc:0.800837	eval-auc:0.738391
# [845]	train-auc:0.800837	eval-auc:0.738391
# [846]	train-auc:0.800911	eval-auc:0.738403
# [847]	train-auc:0.800937	eval-auc:0.73841
# [848]	train-auc:0.801035	eval-auc:0.738404
# [849]	train-auc:0.801205	eval-auc:0.738519
# [850]	train-auc:0.801205	eval-auc:0.738519
# [851]	train-auc:0.801313	eval-auc:0.738497
# [852]	train-auc:0.801381	eval-auc:0.738504
# [853]	train-auc:0.801381	eval-auc:0.738504
# [854]	train-auc:0.801381	eval-auc:0.738504
# [855]	train-auc:0.801381	eval-auc:0.738504
# [856]	train-auc:0.801381	eval-auc:0.738504
# [857]	train-auc:0.801381	eval-auc:0.738504
# [858]	train-auc:0.801444	eval-auc:0.738514
# [859]	train-auc:0.801444	eval-auc:0.738514
# [860]	train-auc:0.801554	eval-auc:0.738533
# [861]	train-auc:0.801554	eval-auc:0.738533
# [862]	train-auc:0.801594	eval-auc:0.738537
# [863]	train-auc:0.801594	eval-auc:0.738537
# [864]	train-auc:0.801594	eval-auc:0.738537
# [865]	train-auc:0.801751	eval-auc:0.738506
# [866]	train-auc:0.801813	eval-auc:0.738534
# [867]	train-auc:0.801813	eval-auc:0.738534
# [868]	train-auc:0.801848	eval-auc:0.738566
# [869]	train-auc:0.801969	eval-auc:0.73863
# [870]	train-auc:0.801969	eval-auc:0.73863
# [871]	train-auc:0.801969	eval-auc:0.73863
# [872]	train-auc:0.801969	eval-auc:0.73863
# [873]	train-auc:0.802001	eval-auc:0.738623
# [874]	train-auc:0.802001	eval-auc:0.738623
# [875]	train-auc:0.802028	eval-auc:0.738615
# [876]	train-auc:0.802049	eval-auc:0.738621
# [877]	train-auc:0.802049	eval-auc:0.738621
# [878]	train-auc:0.802195	eval-auc:0.738634
# [879]	train-auc:0.802195	eval-auc:0.738634
# [880]	train-auc:0.802365	eval-auc:0.738585
# [881]	train-auc:0.80239	eval-auc:0.738587
# [882]	train-auc:0.802433	eval-auc:0.738552
# [883]	train-auc:0.802433	eval-auc:0.738552
# [884]	train-auc:0.802528	eval-auc:0.738536
# [885]	train-auc:0.802528	eval-auc:0.738536
# [886]	train-auc:0.802528	eval-auc:0.738536
# [887]	train-auc:0.802528	eval-auc:0.738536
# [888]	train-auc:0.802528	eval-auc:0.738536
# [889]	train-auc:0.802528	eval-auc:0.738536
# [890]	train-auc:0.802577	eval-auc:0.73852
# [891]	train-auc:0.802577	eval-auc:0.73852
# [892]	train-auc:0.802655	eval-auc:0.738516
# [893]	train-auc:0.802687	eval-auc:0.738522
# [894]	train-auc:0.802778	eval-auc:0.73851
# [895]	train-auc:0.802778	eval-auc:0.73851
# [896]	train-auc:0.802778	eval-auc:0.73851
# [897]	train-auc:0.802799	eval-auc:0.738495
# [898]	train-auc:0.802816	eval-auc:0.738489
# [899]	train-auc:0.802887	eval-auc:0.738458
# [900]	train-auc:0.802887	eval-auc:0.738458
# [901]	train-auc:0.802887	eval-auc:0.738458
# [902]	train-auc:0.802972	eval-auc:0.738435
# [903]	train-auc:0.802972	eval-auc:0.738435
# [904]	train-auc:0.802972	eval-auc:0.738435
# [905]	train-auc:0.802972	eval-auc:0.738435
# [906]	train-auc:0.802972	eval-auc:0.738435
# [907]	train-auc:0.803088	eval-auc:0.738451
# [908]	train-auc:0.803111	eval-auc:0.738467
# [909]	train-auc:0.803111	eval-auc:0.738467
# [910]	train-auc:0.803248	eval-auc:0.738448
# [911]	train-auc:0.803323	eval-auc:0.738457
# [912]	train-auc:0.803395	eval-auc:0.738469
# [913]	train-auc:0.803395	eval-auc:0.738469
# [914]	train-auc:0.803414	eval-auc:0.738468
# [915]	train-auc:0.803545	eval-auc:0.738437
# [916]	train-auc:0.803558	eval-auc:0.738444
# [917]	train-auc:0.803736	eval-auc:0.738524
# [918]	train-auc:0.803715	eval-auc:0.738535
# [919]	train-auc:0.803715	eval-auc:0.738535
# [920]	train-auc:0.803765	eval-auc:0.738559
# [921]	train-auc:0.803765	eval-auc:0.738559
# [922]	train-auc:0.80385	eval-auc:0.738577
# [923]	train-auc:0.80385	eval-auc:0.738577
# [924]	train-auc:0.80385	eval-auc:0.738577
# [925]	train-auc:0.80385	eval-auc:0.738577
# [926]	train-auc:0.80385	eval-auc:0.738577
# [927]	train-auc:0.80385	eval-auc:0.738577
# [928]	train-auc:0.803894	eval-auc:0.738593
# [929]	train-auc:0.803894	eval-auc:0.738593
# [930]	train-auc:0.803894	eval-auc:0.738593
# [931]	train-auc:0.803894	eval-auc:0.738593
# [932]	train-auc:0.803894	eval-auc:0.738593
# [933]	train-auc:0.803894	eval-auc:0.738593
# [934]	train-auc:0.803894	eval-auc:0.738593
# [935]	train-auc:0.803894	eval-auc:0.738593
# [936]	train-auc:0.803998	eval-auc:0.738638
# [937]	train-auc:0.80403	eval-auc:0.738621
# [938]	train-auc:0.80403	eval-auc:0.738621
# [939]	train-auc:0.804057	eval-auc:0.738596
# [940]	train-auc:0.804092	eval-auc:0.738602
# [941]	train-auc:0.804113	eval-auc:0.738597
# [942]	train-auc:0.804113	eval-auc:0.738597
# [943]	train-auc:0.804211	eval-auc:0.738592
# [944]	train-auc:0.804307	eval-auc:0.738698
# [945]	train-auc:0.804427	eval-auc:0.738665
# [946]	train-auc:0.804427	eval-auc:0.738665
# [947]	train-auc:0.80454	eval-auc:0.738664
# [948]	train-auc:0.804587	eval-auc:0.738661
# [949]	train-auc:0.804587	eval-auc:0.738661
# [950]	train-auc:0.804606	eval-auc:0.738657
# [951]	train-auc:0.804642	eval-auc:0.738667
# [952]	train-auc:0.804642	eval-auc:0.738667
# [953]	train-auc:0.804682	eval-auc:0.738654
# [954]	train-auc:0.804713	eval-auc:0.738676
# [955]	train-auc:0.804786	eval-auc:0.738661
# [956]	train-auc:0.80485	eval-auc:0.738635
# [957]	train-auc:0.804923	eval-auc:0.738627
# [958]	train-auc:0.804923	eval-auc:0.738627
# [959]	train-auc:0.804923	eval-auc:0.738627
# [960]	train-auc:0.804923	eval-auc:0.738627
# [961]	train-auc:0.804923	eval-auc:0.738627
# [962]	train-auc:0.804923	eval-auc:0.738627
# [963]	train-auc:0.805017	eval-auc:0.738609
# [964]	train-auc:0.805017	eval-auc:0.738609
# [965]	train-auc:0.805072	eval-auc:0.738621
# [966]	train-auc:0.805123	eval-auc:0.73865
# [967]	train-auc:0.805164	eval-auc:0.738662
# [968]	train-auc:0.805208	eval-auc:0.738646
# [969]	train-auc:0.805211	eval-auc:0.73866
# [970]	train-auc:0.805245	eval-auc:0.738652
# [971]	train-auc:0.805293	eval-auc:0.738628
# [972]	train-auc:0.805379	eval-auc:0.738597
# [973]	train-auc:0.805379	eval-auc:0.738597
# [974]	train-auc:0.805379	eval-auc:0.738597
# [975]	train-auc:0.805379	eval-auc:0.738597
# [976]	train-auc:0.805379	eval-auc:0.738597
# [977]	train-auc:0.805379	eval-auc:0.738597
# [978]	train-auc:0.805396	eval-auc:0.738564
# [979]	train-auc:0.805396	eval-auc:0.738564
# [980]	train-auc:0.805396	eval-auc:0.738564
# [981]	train-auc:0.805461	eval-auc:0.738549
# [982]	train-auc:0.805484	eval-auc:0.738551
# [983]	train-auc:0.805586	eval-auc:0.738581
# [984]	train-auc:0.805623	eval-auc:0.738565
# [985]	train-auc:0.805623	eval-auc:0.738565
# [986]	train-auc:0.805669	eval-auc:0.738551
# [987]	train-auc:0.805727	eval-auc:0.738538
# [988]	train-auc:0.805727	eval-auc:0.738538
# [989]	train-auc:0.805727	eval-auc:0.738538
# [990]	train-auc:0.805836	eval-auc:0.738542
# [991]	train-auc:0.80587	eval-auc:0.738571
# [992]	train-auc:0.80587	eval-auc:0.738571
# [993]	train-auc:0.805942	eval-auc:0.738562
# [994]	train-auc:0.80597	eval-auc:0.738574
# [995]	train-auc:0.805986	eval-auc:0.738565
# [996]	train-auc:0.806053	eval-auc:0.738573
# [997]	train-auc:0.806053	eval-auc:0.738573
# [998]	train-auc:0.806094	eval-auc:0.738553
# [999]	train-auc:0.806094	eval-auc:0.738553
# /Users/syamantak/.pyenv/versions/3.7.0/lib/python3.7/site-packages/numpy/lib/function_base.py:356: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /Users/syamantak/.pyenv/versions/3.7.0/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Finished cross validation
# MSE: 0    0.205321
# dtype: float64
# ACC: 0    0.662546
# dtype: float64
# AUC: 0    0.738728
# dtype: float64
# ACC for t at 210: 0   NaN
# dtype: float64
# Empty DataFrame
# Columns: [average corr]
# Index: []

# %%
columns = list(df.columns)
columns.remove('label')
if rebalance_method == 'up':
    df_rebalance = upsample(df)
if rebalance_method == 'down':
    df_rebalance = downsample(df)
X = df_rebalance[columns]
y = df_rebalance[['label']]

# load JS visualization code to notebook
#shap.initjs()

# train XGBoost model

model = xgb.train(param, xgb.DMatrix(X, label=y), num_boost_round)

# explain the model's predictions using SHAP values
# (same syntax works for LightGBM, CatBoost, and scikit-learn models)
#explainer = shap.TreeExplainer(model)
#shap_values = explainer.shap_values(X)

# visualize the first prediction's explanation
#shap.force_plot(explainer.expected_value, shap_values[0,:], X.iloc[0,:])
# Out:
# 1.0    56676
# 0.0    56676
# Name: label, dtype: int64

# %%
with open(path+event+'_xgb_model_'+str(start_hour)+'_hrs.dat', 'wb') as file:
    pickle.dump(model, file)
