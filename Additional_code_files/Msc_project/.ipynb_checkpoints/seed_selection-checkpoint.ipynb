# %%
import csv
import pandas as pd

# %%
path = "/Users/jay/MSC_WSBDA/MSc_Thesis/Msc_project/Data/"

# %%
neighbour_degree= pd.read_csv(path+'filtered_70013users.csv')

# %%
len(neighbour_degree)
# Out:
# 20166

# %%
neighbour_degree
# Out:
#                 created_at  user_favourites_count  followers_count  \
# 0      2009-04-26 23:49:25                      0                9
# 1      2010-11-17 20:55:07                      0                7
# 2      2009-02-04 09:21:27                   3669             5216
# 3      2011-10-07 08:28:59                     20              641
# 4      2009-03-12 06:35:50                   2316           185972
# 5      2009-10-08 15:31:01                      3              102
# 6      2009-03-14 23:01:51                      0            74388
# 7      2009-02-23 00:24:44                     55              112
# 8      2009-03-12 01:13:58                    421              281
# 9      2009-10-13 17:37:40                    240            23143
# 10     2010-09-26 19:02:35                    382              279
# 11     2008-04-19 11:57:34                     86            13127
# 12     2010-06-03 14:31:31                   5663             8504
# ...

# %%
seeds = neighbour_degree[1015:1025]

# %%
seeds.to_csv(path+'mid_1015-1024_seeds_avg_neighbour_degree.csv',index=False)

# %%
seeds1= pd.read_csv(path+'mid_31-40_seeds_avg_neighbour_degree.csv')

# %%
seeds
# Out:
#                created_at  user_favourites_count  followers_count  \
# 1015  2008-10-19 06:21:44                    285              816
# 1016  2008-11-24 09:34:58                    933              474
# 1017  2009-12-05 18:22:59                   7261             1447
# 1018  2007-12-22 20:18:56                   3524             3860
# 1019  2010-05-09 18:44:07                      0               10
# 1020  2009-04-18 22:22:55                     71              283
# 1021  2012-01-18 23:58:48                      0               95
# 1022  2009-08-16 18:55:49                      0              417
# 1023  2009-03-13 15:17:04                     17              344
# 1024  2009-03-23 00:54:03                   1029             4572
#
#       friends_count    user_id  user_listed_count  user_statuses_count  \
# 1015            728   16848743                 29                 5420
# 1016            687   17589133                 28                10483
# ...

# %%
neighbour_degree[(neighbour_degree['avg_neighbour_degree'] > 140) & (neighbour_degree['avg_neighbour_degree'] < 145)]
# Out:
#                created_at  user_favourites_count  followers_count  \
# 937   2012-03-28 12:30:32                  13475             1643
# 938   2008-12-13 17:28:50                   9962             5660
# 939   2012-01-09 21:10:53                      0               38
# 940   2010-09-23 10:26:27                      0              187
# 941   2010-04-11 21:09:45                    141             1368
# 942   2010-04-18 15:56:22                     35              237
# 943   2009-12-24 01:33:34                     86             2387
# 944   2009-03-20 04:14:01                    733             7965
# 945   2010-10-13 18:00:16                      0               17
# 946   2010-02-10 09:10:49                   1406              980
# 947   2011-10-20 04:01:14                      0                5
# 948   2009-03-27 07:32:23                    235              467
# 949   2010-01-26 23:08:09                    414              800
# ...

# %%
neighbour_degree= pd.read_csv(path+'70013users_new.csv')

# %%
sorted_df = neighbour_degree.sort_values(by = ['avg_neighbour_degree'],ascending = False)

# %%
seeds = sorted_df[0:5]

# %%
seeds
# Out:
#                 created_at  user_favourites_count  followers_count  \
# 22956  2009-07-13 03:45:06                      0             2927
# 55713  2009-02-02 20:25:41                      1              404
# 50954  2011-04-30 19:51:45                     82               98
# 33519  2009-07-19 21:10:08                      0                7
# 35831  2011-05-02 12:15:12                      0                6
#
#        friends_count    user_id  user_listed_count  user_statuses_count  \
# 22956           3788   56278217                 46                24843
# 55713            439   19928966                 50                 3641
# 50954            191  290720399                  0                 1608
# 33519              9   58294702                  1                  128
# 35831             35  291662107                  0                  235
#
#            source_candidates target_nodes  user_created_days  \
# 22956           [2758, 5800]    [3359851]               3165
# ...

# %%
seeds.to_csv(path+'0_5_5_not_filtered_seeds_avg_neighbour_degree.csv',index=False)

# %% [markdown]
# ## Avg Neighbour Betweenness Centrality

# %%
neighbour_betweenness= pd.read_csv(path+'70013users_betweenness_centrality.csv')

# %%
neighbour_betweenness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70013 entries, 0 to 70012
# Data columns (total 18 columns):
# created_at                          70013 non-null object
# user_favourites_count               70013 non-null int64
# followers_count                     70013 non-null int64
# friends_count                       70013 non-null int64
# user_id                             70013 non-null int64
# user_listed_count                   70013 non-null int64
# user_statuses_count                 70013 non-null int64
# source_candidates                   70013 non-null object
# target_nodes                        70013 non-null object
# user_created_days                   70013 non-null int64
# normalized_user_statuses_count      70013 non-null float64
# normalized_user_followers_count     70013 non-null float64
# normalized_user_favourites_count    70013 non-null float64
# normalized_user_listed_count        70013 non-null float64
# ...

# %%
sorted_df = neighbour_betweenness.sort_values(by = ['avg_neighbour_betweenness'],ascending = False)

# %%
seeds = sorted_df[0:10]

# %%
seeds
# Out:
#                 created_at  user_favourites_count  followers_count  \
# 16327  2008-12-04 15:30:11                   1854             9496
# 16339  2009-01-30 04:00:12                    390             6435
# 12541  2009-03-01 04:24:25                    225              117
# 29617  2008-12-02 23:03:04                     31               17
# 7186   2011-03-16 06:22:51                  16991             5544
# 28138  2009-06-03 17:38:07                   1259         50709301
# 15957  2008-07-04 07:44:06                      0             2962
# 57919  2008-09-20 20:09:13                      1           658931
# 15958  2009-03-03 05:51:45                    165              199
# 15959  2008-10-30 05:41:01                      7             1544
#
#        friends_count    user_id  user_listed_count  user_statuses_count  \
# 16327           6323   17869922                206                 8029
# 16339           1920   19753142                174                 3920
# ...

# %%
seeds.to_csv(path+'0_10_10_seeds_avg_neighbour_betweenness.csv',index=False)
